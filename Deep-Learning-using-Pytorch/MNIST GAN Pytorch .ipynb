# %% [markdown]
# # Generative Adverserial Networks in PyTorch
#
# Deep neural networks are used mainly for supervised learning: classification or regression. Generative Adverserial Networks or GANs, however, use neural networks for a very different purpose: Generative modeling
#
# > Generative modeling is an unsupervised learning task in machine learning that involves automatically discovering and learning the regularities or patterns in input data in such a way that the model can be used to generate or output new examples that plausibly could have been drawn from the original dataset.
# While there are many approaches used for generative modeling, a Generative Adverserial Network takes the following approach:
#
# ![GAN Flowchart](https://i.imgur.com/6NMdO9u.png)
#
# There are two neural networks: a *Generator* and a *Discriminator*. The generator generates a "fake" sample given a random vector/matrix, and the discriminator attempts to detect whether a given sample is "real" (picked from the training data) or "fake" (generated by the generator). Training happens in tandem: we train the discriminator for a few epochs, then train the generator for a few epochs, and repeat. This way both the generator and the discriminator get better at doing their jobs. This rather simple approach can lead to some astounding results.
# GANs however, can be notoriously difficult to train, and are extremely sensitive to hyperparameters, activation functions and regularization. In this tutorial, we'll train a GAN to generate images of handwritten digits similar to those from the MNIST database.

# %% [markdown]
# ## Load the Data
#
# We begin by downloading and importing the data as a PyTorch dataset using the `MNIST` helper class from `torchvision.datasets`.

# %%
import torch
import torchvision
from torchvision.transforms import ToTensor, Normalize, Compose
from torchvision.datasets import MNIST

mnist = MNIST(root='data', 
              train=True, 
              download=True,
              transform=Compose([ToTensor(), Normalize(mean=(0.5,), std=(0.5,))]))
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to data/MNIST/raw/train-images-idx3-ubyte.gz
# 100.1%
# Extracting data/MNIST/raw/train-images-idx3-ubyte.gz to data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to data/MNIST/raw/train-labels-idx1-ubyte.gz
# 113.5%
# Extracting data/MNIST/raw/train-labels-idx1-ubyte.gz to data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100.4%
# Extracting data/MNIST/raw/t10k-images-idx3-ubyte.gz to data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 180.4%
# Extracting data/MNIST/raw/t10k-labels-idx1-ubyte.gz to data/MNIST/raw
# Processing...
# Done!

# %%
img, label = mnist[0]
print('Label: ', label)
print(img[:,10:15,10:15])
torch.min(img), torch.max(img)
# Out:
# Label:  5
# tensor([[[-0.9922,  0.2078,  0.9843, -0.2941, -1.0000],
#          [-1.0000,  0.0902,  0.9843,  0.4902, -0.9843],
#          [-1.0000, -0.9137,  0.4902,  0.9843, -0.4510],
#          [-1.0000, -1.0000, -0.7255,  0.8902,  0.7647],
#          [-1.0000, -1.0000, -1.0000, -0.3647,  0.8824]]])
# (tensor(-1.), tensor(1.))

# %% [markdown]
# As expected, the pixel values range from -1 to 1. Let's define a helper to denormalize and view the images. This function will also be useful for viewing the generated images.

# %%
def denorm(x):
    out = (x + 1) / 2
    return out.clamp(0, 1)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

img_norm = denorm(img)
plt.imshow(img_norm[0], cmap='gray')
print('Label:', label)
# Out:
# Label: 5

# %% [markdown]
# Finally, let's create a dataloader to load the images in batches.

# %%
from torch.utils.data import DataLoader

batch_size = 100
data_loader = DataLoader(mnist, batch_size, shuffle=True)

# %%
for img_batch, label_batch in data_loader:
    print('first batch')
    print(img_batch.shape)
    plt.imshow(img_batch[0][0], cmap='gray')
    print(label_batch)
    break
# Out:
# first batch
# torch.Size([100, 1, 28, 28])
# tensor([5, 4, 7, 2, 9, 9, 0, 0, 0, 7, 1, 5, 8, 4, 2, 9, 2, 3, 1, 4, 2, 4, 7, 1,
#         9, 9, 3, 8, 1, 2, 0, 8, 9, 9, 8, 5, 7, 9, 9, 3, 6, 7, 6, 0, 5, 3, 9, 8,
#         1, 3, 9, 6, 1, 1, 6, 0, 2, 3, 3, 8, 7, 7, 7, 4, 7, 0, 3, 8, 8, 4, 5, 6,
#         0, 5, 8, 2, 2, 4, 1, 4, 4, 5, 0, 6, 8, 2, 9, 2, 5, 0, 4, 3, 1, 1, 5, 7,
#         0, 8, 9, 1])

# %% [markdown]
# We'll also create a `device` which can be used to move the data and models to a GPU, if one is available.

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
device
# Out:
# device(type='cpu')

# %% [markdown]
# ## Discriminator Network
#
# The discriminator takes an image as input, and tries to classify it as "real" or "generated". In this sense, it's like any other neural network. While we can use a CNN for the discriminator, we'll use a simple feedforward network with 3 linear layers to keep things since. We'll treat each 28x28 image as a vector of size 784.

# %%
image_size = 784
hidden_size = 256

# %%
import torch.nn as nn

D = nn.Sequential(
    nn.Linear(image_size, hidden_size),
    nn.LeakyReLU(0.2),
    nn.Linear(hidden_size, hidden_size),
    nn.LeakyReLU(0.2),
    nn.Linear(hidden_size, 1),
    nn.Sigmoid())

# %% [markdown]
# We use the Leaky ReLU activation for the discriminator.
#
#
# >  Different from the regular ReLU function, Leaky ReLU allows the pass of a small gradient signal for negative values. As a result, it makes the gradients from the discriminator flows stronger into the generator. Instead of passing a gradient (slope) of 0 in the back-prop pass, it passes a small negative gradient.
#
# Just like any other binary classification model, the output of the discriminator is a single number between 0 and 1, which can be interpreted as the probability of the input image being fake i.e. generated.
#
# Let's move the discriminator model to the chosen device.

# %%
D.to(device);

# %% [markdown]
# ## Generator Network
#
# The input to the generator is typically a vector or a matrix which is used as a seed for generating an image. Once again, to keep things simple, we'll use a feedfoward neural network with 3 layers, and the output will be a vector of size 784, which can be transformed to a 28x28 px image.

# %%
latent_size = 64
#it acts like 64 learning params

# %%
G = nn.Sequential(
    nn.Linear(latent_size, hidden_size),
    nn.ReLU(),
    nn.Linear(hidden_size, hidden_size),
    nn.ReLU(),
    nn.Linear(hidden_size, image_size),
    nn.Tanh())

# %% [markdown]
# We use the TanH activation function for the output layer of the generator.
#
#
# > "The ReLU activation (Nair & Hinton, 2010) is used in the generator with the exception of the output layer which uses the Tanh function. We observed that using a bounded activation allowed the model to learn more quickly to saturate and cover the color space of the training distribution. Within the discriminator we found the leaky rectified activation (Maas et al., 2013) (Xu et al., 2015) to work well, especially for higher resolution modeling."
#
# Note that since the outputs of the TanH activation lie in the range `[-1,1]`, we have applied the same transformation to the images in the training dataset. Let's generate an output vector using the generator and view it as an image by transforming and denormalizing the output.

# %%
y = G(torch.randn(2, latent_size))
gen_imgs = denorm(y.reshape((-1, 28,28)).detach())

# %%
plt.imshow(gen_imgs[0], cmap='gray');

# %%
plt.imshow(gen_imgs[1], cmap='gray');

# %%
G.to(device);

# %% [markdown]
# ## Discriminator Training
#
# Since the discriminator is a binary classification model, we can use the binary cross entropy loss function to quantify how well it is able to differentiate between real and generated images.

# %%
criterion = nn.BCELoss()
d_optimizer = torch.optim.Adam(D.parameters(), lr=0.0002)

# %%
def reset_grad():
    d_optimizer.zero_grad()
    g_optimizer.zero_grad()

def train_discriminator(images):
    # Create the labels which are later used as input for the BCE loss
    real_labels = torch.ones(batch_size, 1).to(device)
    fake_labels = torch.zeros(batch_size, 1).to(device)
        
    # Loss for real images
    outputs = D(images)
    d_loss_real = criterion(outputs, real_labels)
    real_score = outputs

    # Loss for fake images
    z = torch.randn(batch_size, latent_size).to(device)
    fake_images = G(z)
    outputs = D(fake_images)
    d_loss_fake = criterion(outputs, fake_labels)
    fake_score = outputs

    # Combine losses
    d_loss = d_loss_real + d_loss_fake
    # Reset gradients
    reset_grad()
    # Compute gradients
    d_loss.backward()
    # Adjust the parameters using backprop
    d_optimizer.step()
    
    return d_loss, real_score, fake_score

# %% [markdown]
# Here are the steps involved in training the discriminator.
#
# - We expect the discriminator to output 1 if the image was picked from the real MNIST dataset, and 0 if it was generated.
#
# - We first pass a batch of real images, and compute the loss, setting the target labels to 1.
#
# - Then, we generate a batch of fake images using the generator, pass them into the discriminator, and compute the loss, setting the target labels to 0.
#
# - Finally we add the two losses and use the overall loss to perform gradient descent to adjust the weights of the discriminator.
#
# It's important to note that we don't change the weights of the generator model while training the discriminator (`d_optimizer` only affects the `D.parameters()`)

# %% [markdown]
# ## Generator Training
#
# Since the outputs of the generator are images, it's not obvious how we can train the generator.We will use the discriminator as a part of the loss function. Here's how it works:
#
# - We generate a batch of images using the generator, pass the into the discriminator.
#
# - We calculate the loss by setting the target labels to 1 i.e. real. We do this because the generator's objective is to "fool" the discriminator.
#
# - We use the loss to perform gradient descent i.e. change the weights of the generator, so it gets better at generating real-like images.

# %%
g_optimizer = torch.optim.Adam(G.parameters(), lr=0.0002)

# %%
def train_generator():
    # Generate fake images and calculate loss
    z = torch.randn(batch_size, latent_size).to(device)
    fake_images = G(z)
    labels = torch.ones(batch_size, 1).to(device)
    g_loss = criterion(D(fake_images), labels)

    # Backprop and optimize
    reset_grad()
    g_loss.backward()
    g_optimizer.step()
    return g_loss, fake_images

# %% [markdown]
# ## Training the Model
#
# Let's create a directory where we can save intermediate outputs from the generator to visually inspect the progress of the model

# %%
import os

sample_dir = 'samples'
if not os.path.exists(sample_dir):
    os.makedirs(sample_dir)

# %% [markdown]
# Let's save a batch of real images that we can use for visual comparision while looking at the generated images.

# %%
from IPython.display import Image
from torchvision.utils import save_image

# Save some real images
for images, _ in data_loader:
    images = images.reshape(images.size(0), 1, 28, 28)
    save_image(denorm(images), os.path.join(sample_dir, 'real_images.png'), nrow=10)
    break
   
Image(os.path.join(sample_dir, 'real_images.png'))

# %% [markdown]
# We'll also define a helper function to save a batch of generated images to disk at the end of every epoch. We'll use a fixed set of input vectors to the generator to see how the individual generated images evolve over time as we train the model.

# %%
sample_vectors = torch.randn(batch_size, latent_size).to(device)

def save_fake_images(index):
    fake_images = G(sample_vectors)
    fake_images = fake_images.reshape(fake_images.size(0), 1, 28, 28)
    fake_fname = 'fake_images-{0:0=4d}.png'.format(index)
    print('Saving', fake_fname)
    save_image(denorm(fake_images), os.path.join(sample_dir, fake_fname), nrow=10)
    
# Before training
save_fake_images(0)
Image(os.path.join(sample_dir, 'fake_images-0000.png'))
# Out:
# Saving fake_images-0000.png

# %% [markdown]
# We are now ready to train the model. In each epoch, we train the discriminator first, and then the generator. The training might take a while if you're not using a GPU.

# %%
# %%time

num_epochs = 300
total_step = len(data_loader)
d_losses, g_losses, real_scores, fake_scores = [], [], [], []

for epoch in range(num_epochs):
    for i, (images, _) in enumerate(data_loader):
        # Load a batch & transform to vectors
        images = images.reshape(batch_size, -1).to(device)
        
        # Train the discriminator and generator
        d_loss, real_score, fake_score = train_discriminator(images)
        g_loss, fake_images = train_generator()
        
        # Inspect the losses
        if (i+1) % 200 == 0:
            d_losses.append(d_loss.item())
            g_losses.append(g_loss.item())
            real_scores.append(real_score.mean().item())
            fake_scores.append(fake_score.mean().item())
            print('Epoch [{}/{}], Step [{}/{}], d_loss: {:.4f}, g_loss: {:.4f}, D(x): {:.2f}, D(G(z)): {:.2f}' 
                  .format(epoch, num_epochs, i+1, total_step, d_loss.item(), g_loss.item(), 
                          real_score.mean().item(), fake_score.mean().item()))
        
    # Sample and save images
    save_fake_images(epoch+1)
# Out:
# Epoch [0/300], Step [200/600], d_loss: 0.0384, g_loss: 4.1603, D(x): 0.99, D(G(z)): 0.03
# Epoch [0/300], Step [400/600], d_loss: 0.0472, g_loss: 6.4702, D(x): 0.98, D(G(z)): 0.02
# Epoch [0/300], Step [600/600], d_loss: 0.0313, g_loss: 5.4585, D(x): 0.98, D(G(z)): 0.01
# Saving fake_images-0001.png
# Epoch [1/300], Step [200/600], d_loss: 0.1087, g_loss: 4.7566, D(x): 0.99, D(G(z)): 0.08
# Epoch [1/300], Step [400/600], d_loss: 0.3761, g_loss: 3.1303, D(x): 0.89, D(G(z)): 0.17
# Epoch [1/300], Step [600/600], d_loss: 0.2217, g_loss: 4.4405, D(x): 0.95, D(G(z)): 0.12
# Saving fake_images-0002.png
# Epoch [2/300], Step [200/600], d_loss: 0.2344, g_loss: 4.1008, D(x): 0.93, D(G(z)): 0.08
# Epoch [2/300], Step [400/600], d_loss: 0.2547, g_loss: 4.0524, D(x): 0.90, D(G(z)): 0.10
# Epoch [2/300], Step [600/600], d_loss: 0.3860, g_loss: 3.4349, D(x): 0.90, D(G(z)): 0.18
# Saving fake_images-0003.png
# Epoch [3/300], Step [200/600], d_loss: 0.4282, g_loss: 4.3679, D(x): 0.83, D(G(z)): 0.08
# Epoch [3/300], Step [400/600], d_loss: 0.4571, g_loss: 3.1345, D(x): 0.81, D(G(z)): 0.10
# Epoch [3/300], Step [600/600], d_loss: 0.1723, g_loss: 3.9866, D(x): 0.94, D(G(z)): 0.09
# Saving fake_images-0004.png
# Epoch [4/300], Step [200/600], d_loss: 0.7559, g_loss: 1.7598, D(x): 0.78, D(G(z)): 0.21
# Epoch [4/300], Step [400/600], d_loss: 0.3957, g_loss: 2.9308, D(x): 0.86, D(G(z)): 0.15
# Epoch [4/300], Step [600/600], d_loss: 0.2638, g_loss: 3.1356, D(x): 0.92, D(G(z)): 0.11
# Saving fake_images-0005.png
# Epoch [5/300], Step [200/600], d_loss: 0.2866, g_loss: 4.0112, D(x): 0.94, D(G(z)): 0.16
# Epoch [5/300], Step [400/600], d_loss: 0.4057, g_loss: 2.6294, D(x): 0.87, D(G(z)): 0.10
# Epoch [5/300], Step [600/600], d_loss: 0.0726, g_loss: 4.7465, D(x): 0.96, D(G(z)): 0.03
# Saving fake_images-0006.png
# Epoch [6/300], Step [200/600], d_loss: 0.5181, g_loss: 3.1370, D(x): 0.86, D(G(z)): 0.15
# Epoch [6/300], Step [400/600], d_loss: 0.1385, g_loss: 4.5260, D(x): 0.95, D(G(z)): 0.06
# Epoch [6/300], Step [600/600], d_loss: 0.1454, g_loss: 5.5308, D(x): 0.94, D(G(z)): 0.02
# Saving fake_images-0007.png
# Epoch [7/300], Step [200/600], d_loss: 0.1952, g_loss: 4.6954, D(x): 0.96, D(G(z)): 0.12
# Epoch [7/300], Step [400/600], d_loss: 0.1707, g_loss: 4.8725, D(x): 0.96, D(G(z)): 0.07
# Epoch [7/300], Step [600/600], d_loss: 0.1915, g_loss: 3.3949, D(x): 0.94, D(G(z)): 0.06
# Saving fake_images-0008.png
# Epoch [8/300], Step [200/600], d_loss: 0.3451, g_loss: 4.1994, D(x): 0.89, D(G(z)): 0.04
# Epoch [8/300], Step [400/600], d_loss: 0.1840, g_loss: 5.5376, D(x): 0.94, D(G(z)): 0.02
# Epoch [8/300], Step [600/600], d_loss: 0.1599, g_loss: 4.6554, D(x): 0.97, D(G(z)): 0.06
# Saving fake_images-0009.png
# Epoch [9/300], Step [200/600], d_loss: 0.2986, g_loss: 3.7014, D(x): 0.91, D(G(z)): 0.10
# Epoch [9/300], Step [400/600], d_loss: 0.1205, g_loss: 3.5593, D(x): 0.96, D(G(z)): 0.05
# Epoch [9/300], Step [600/600], d_loss: 0.1853, g_loss: 5.6681, D(x): 0.94, D(G(z)): 0.03
# Saving fake_images-0010.png
# Epoch [10/300], Step [200/600], d_loss: 0.1249, g_loss: 4.0133, D(x): 0.95, D(G(z)): 0.03
# Epoch [10/300], Step [400/600], d_loss: 0.1452, g_loss: 4.7997, D(x): 0.96, D(G(z)): 0.06
# Epoch [10/300], Step [600/600], d_loss: 0.1122, g_loss: 6.0047, D(x): 0.96, D(G(z)): 0.02
# Saving fake_images-0011.png
# Epoch [11/300], Step [200/600], d_loss: 0.2128, g_loss: 7.4043, D(x): 0.91, D(G(z)): 0.01
# Epoch [11/300], Step [400/600], d_loss: 0.2199, g_loss: 6.1187, D(x): 0.92, D(G(z)): 0.02
# Epoch [11/300], Step [600/600], d_loss: 0.1002, g_loss: 4.8068, D(x): 0.97, D(G(z)): 0.06
# Saving fake_images-0012.png
# Epoch [12/300], Step [200/600], d_loss: 0.0706, g_loss: 4.9127, D(x): 0.98, D(G(z)): 0.04
# Epoch [12/300], Step [400/600], d_loss: 0.1731, g_loss: 5.4091, D(x): 0.93, D(G(z)): 0.01
# Epoch [12/300], Step [600/600], d_loss: 0.1247, g_loss: 7.1225, D(x): 0.96, D(G(z)): 0.05
# Saving fake_images-0013.png
# Epoch [13/300], Step [200/600], d_loss: 0.1195, g_loss: 5.9746, D(x): 0.95, D(G(z)): 0.01
# Epoch [13/300], Step [400/600], d_loss: 0.1005, g_loss: 5.7115, D(x): 0.96, D(G(z)): 0.04
# Epoch [13/300], Step [600/600], d_loss: 0.1201, g_loss: 6.0056, D(x): 0.95, D(G(z)): 0.01
# Saving fake_images-0014.png
# Epoch [14/300], Step [200/600], d_loss: 0.2257, g_loss: 4.4890, D(x): 0.92, D(G(z)): 0.05
# Epoch [14/300], Step [400/600], d_loss: 0.2975, g_loss: 6.2336, D(x): 0.92, D(G(z)): 0.04
# Epoch [14/300], Step [600/600], d_loss: 0.1974, g_loss: 4.5738, D(x): 0.96, D(G(z)): 0.08
# Saving fake_images-0015.png
# Epoch [15/300], Step [200/600], d_loss: 0.1840, g_loss: 4.3894, D(x): 0.95, D(G(z)): 0.08
# Epoch [15/300], Step [400/600], d_loss: 0.1918, g_loss: 5.4764, D(x): 0.98, D(G(z)): 0.10
# Epoch [15/300], Step [600/600], d_loss: 0.1644, g_loss: 5.7283, D(x): 0.99, D(G(z)): 0.12
# Saving fake_images-0016.png
# Epoch [16/300], Step [200/600], d_loss: 0.1621, g_loss: 5.9116, D(x): 0.93, D(G(z)): 0.03
# Epoch [16/300], Step [400/600], d_loss: 0.2269, g_loss: 4.3814, D(x): 0.98, D(G(z)): 0.14
# Epoch [16/300], Step [600/600], d_loss: 0.2264, g_loss: 4.6849, D(x): 0.95, D(G(z)): 0.07
# Saving fake_images-0017.png
# Epoch [17/300], Step [200/600], d_loss: 0.2219, g_loss: 5.9346, D(x): 0.93, D(G(z)): 0.03
# Epoch [17/300], Step [400/600], d_loss: 0.0953, g_loss: 6.1147, D(x): 0.97, D(G(z)): 0.04
# Epoch [17/300], Step [600/600], d_loss: 0.2059, g_loss: 5.8465, D(x): 0.89, D(G(z)): 0.01
# Saving fake_images-0018.png
# Epoch [18/300], Step [200/600], d_loss: 0.2937, g_loss: 4.3662, D(x): 0.90, D(G(z)): 0.02
# Epoch [18/300], Step [400/600], d_loss: 0.2906, g_loss: 4.3632, D(x): 0.92, D(G(z)): 0.02
# Epoch [18/300], Step [600/600], d_loss: 0.3349, g_loss: 4.9554, D(x): 0.88, D(G(z)): 0.02
# Saving fake_images-0019.png
# Epoch [19/300], Step [200/600], d_loss: 0.8258, g_loss: 6.0699, D(x): 0.97, D(G(z)): 0.37
# Epoch [19/300], Step [400/600], d_loss: 0.2446, g_loss: 5.9909, D(x): 0.93, D(G(z)): 0.03
# Epoch [19/300], Step [600/600], d_loss: 0.1093, g_loss: 7.1117, D(x): 0.96, D(G(z)): 0.02
# Saving fake_images-0020.png
# Epoch [20/300], Step [200/600], d_loss: 0.2480, g_loss: 3.9613, D(x): 0.93, D(G(z)): 0.04
# Epoch [20/300], Step [400/600], d_loss: 0.2364, g_loss: 4.6797, D(x): 0.93, D(G(z)): 0.07
# Epoch [20/300], Step [600/600], d_loss: 0.1734, g_loss: 5.2919, D(x): 0.95, D(G(z)): 0.08
# Saving fake_images-0021.png
# Epoch [21/300], Step [200/600], d_loss: 0.2739, g_loss: 5.2361, D(x): 0.89, D(G(z)): 0.02
# Epoch [21/300], Step [400/600], d_loss: 0.2059, g_loss: 6.0732, D(x): 0.92, D(G(z)): 0.01
# Epoch [21/300], Step [600/600], d_loss: 0.2220, g_loss: 4.9859, D(x): 0.96, D(G(z)): 0.12
# Saving fake_images-0022.png
# Epoch [22/300], Step [200/600], d_loss: 0.2404, g_loss: 5.6263, D(x): 0.94, D(G(z)): 0.08
# Epoch [22/300], Step [400/600], d_loss: 0.3115, g_loss: 7.1618, D(x): 0.89, D(G(z)): 0.01
# Epoch [22/300], Step [600/600], d_loss: 0.2836, g_loss: 5.1112, D(x): 0.97, D(G(z)): 0.15
# Saving fake_images-0023.png
# Epoch [23/300], Step [200/600], d_loss: 0.1636, g_loss: 4.6037, D(x): 0.95, D(G(z)): 0.05
# Epoch [23/300], Step [400/600], d_loss: 0.2455, g_loss: 4.1890, D(x): 0.93, D(G(z)): 0.09
# Epoch [23/300], Step [600/600], d_loss: 0.3625, g_loss: 4.3646, D(x): 0.88, D(G(z)): 0.03
# Saving fake_images-0024.png
# Epoch [24/300], Step [200/600], d_loss: 0.3835, g_loss: 4.5021, D(x): 0.91, D(G(z)): 0.07
# Epoch [24/300], Step [400/600], d_loss: 0.2359, g_loss: 4.7335, D(x): 0.90, D(G(z)): 0.03
# Epoch [24/300], Step [600/600], d_loss: 0.2121, g_loss: 5.7860, D(x): 0.91, D(G(z)): 0.02
# Saving fake_images-0025.png
# Epoch [25/300], Step [200/600], d_loss: 0.2650, g_loss: 3.4166, D(x): 0.93, D(G(z)): 0.09
# Epoch [25/300], Step [400/600], d_loss: 0.2895, g_loss: 4.1411, D(x): 0.93, D(G(z)): 0.10
# Epoch [25/300], Step [600/600], d_loss: 0.4704, g_loss: 3.3931, D(x): 0.87, D(G(z)): 0.12
# Saving fake_images-0026.png
# Epoch [26/300], Step [200/600], d_loss: 0.3376, g_loss: 4.7157, D(x): 0.88, D(G(z)): 0.04
# Epoch [26/300], Step [400/600], d_loss: 0.1685, g_loss: 4.4571, D(x): 0.96, D(G(z)): 0.06
# Epoch [26/300], Step [600/600], d_loss: 0.2961, g_loss: 2.9434, D(x): 0.91, D(G(z)): 0.10
# Saving fake_images-0027.png
# Epoch [27/300], Step [200/600], d_loss: 0.2364, g_loss: 4.0679, D(x): 0.93, D(G(z)): 0.08
# Epoch [27/300], Step [400/600], d_loss: 0.2410, g_loss: 4.7542, D(x): 0.94, D(G(z)): 0.12
# Epoch [27/300], Step [600/600], d_loss: 0.2287, g_loss: 4.2680, D(x): 0.92, D(G(z)): 0.07
# Saving fake_images-0028.png
# Epoch [28/300], Step [200/600], d_loss: 0.2835, g_loss: 4.4931, D(x): 0.92, D(G(z)): 0.07
# Epoch [28/300], Step [400/600], d_loss: 0.1692, g_loss: 6.2726, D(x): 0.93, D(G(z)): 0.04
# Epoch [28/300], Step [600/600], d_loss: 0.2191, g_loss: 6.7807, D(x): 0.96, D(G(z)): 0.10
# Saving fake_images-0029.png
# Epoch [29/300], Step [200/600], d_loss: 0.2544, g_loss: 5.2001, D(x): 0.95, D(G(z)): 0.10
# Epoch [29/300], Step [400/600], d_loss: 0.1990, g_loss: 7.2038, D(x): 0.95, D(G(z)): 0.07
# Epoch [29/300], Step [600/600], d_loss: 0.1597, g_loss: 5.9193, D(x): 0.93, D(G(z)): 0.03
# Saving fake_images-0030.png
# Epoch [30/300], Step [200/600], d_loss: 0.1140, g_loss: 5.4120, D(x): 0.97, D(G(z)): 0.05
# Epoch [30/300], Step [400/600], d_loss: 0.3597, g_loss: 5.0299, D(x): 0.94, D(G(z)): 0.12
# Epoch [30/300], Step [600/600], d_loss: 0.3442, g_loss: 4.8052, D(x): 0.92, D(G(z)): 0.13
# Saving fake_images-0031.png
# Epoch [31/300], Step [200/600], d_loss: 0.3328, g_loss: 3.8841, D(x): 0.89, D(G(z)): 0.08
# Epoch [31/300], Step [400/600], d_loss: 0.2628, g_loss: 4.4008, D(x): 0.91, D(G(z)): 0.03
# Epoch [31/300], Step [600/600], d_loss: 0.4953, g_loss: 3.6181, D(x): 0.85, D(G(z)): 0.08
# Saving fake_images-0032.png
# Epoch [32/300], Step [200/600], d_loss: 0.4560, g_loss: 3.9260, D(x): 0.88, D(G(z)): 0.08
# Epoch [32/300], Step [400/600], d_loss: 0.2725, g_loss: 4.6138, D(x): 0.93, D(G(z)): 0.09
# Epoch [32/300], Step [600/600], d_loss: 0.5835, g_loss: 3.3887, D(x): 0.89, D(G(z)): 0.19
# Saving fake_images-0033.png
# Epoch [33/300], Step [200/600], d_loss: 0.4585, g_loss: 2.8872, D(x): 0.87, D(G(z)): 0.10
# Epoch [33/300], Step [400/600], d_loss: 0.4062, g_loss: 3.3935, D(x): 0.92, D(G(z)): 0.19
# Epoch [33/300], Step [600/600], d_loss: 0.4479, g_loss: 3.1244, D(x): 0.83, D(G(z)): 0.08
# Saving fake_images-0034.png
# Epoch [34/300], Step [200/600], d_loss: 0.4340, g_loss: 2.6143, D(x): 0.87, D(G(z)): 0.13
# Epoch [34/300], Step [400/600], d_loss: 0.4108, g_loss: 2.3542, D(x): 0.93, D(G(z)): 0.18
# Epoch [34/300], Step [600/600], d_loss: 0.4416, g_loss: 3.3008, D(x): 0.92, D(G(z)): 0.17
# Saving fake_images-0035.png
# Epoch [35/300], Step [200/600], d_loss: 0.2348, g_loss: 3.8114, D(x): 0.93, D(G(z)): 0.09
# Epoch [35/300], Step [400/600], d_loss: 0.3637, g_loss: 2.6965, D(x): 0.87, D(G(z)): 0.09
# Epoch [35/300], Step [600/600], d_loss: 0.5390, g_loss: 4.0909, D(x): 0.86, D(G(z)): 0.13
# Saving fake_images-0036.png
# Epoch [36/300], Step [200/600], d_loss: 0.4119, g_loss: 3.2401, D(x): 0.90, D(G(z)): 0.12
# Epoch [36/300], Step [400/600], d_loss: 0.3555, g_loss: 2.5027, D(x): 0.92, D(G(z)): 0.17
# Epoch [36/300], Step [600/600], d_loss: 0.3964, g_loss: 3.6924, D(x): 0.85, D(G(z)): 0.09
# Saving fake_images-0037.png
# Epoch [37/300], Step [200/600], d_loss: 0.2239, g_loss: 3.6679, D(x): 0.92, D(G(z)): 0.09
# Epoch [37/300], Step [400/600], d_loss: 0.3799, g_loss: 3.1888, D(x): 0.89, D(G(z)): 0.11
# Epoch [37/300], Step [600/600], d_loss: 0.3669, g_loss: 4.8679, D(x): 0.92, D(G(z)): 0.13
# Saving fake_images-0038.png
# Epoch [38/300], Step [200/600], d_loss: 0.4871, g_loss: 3.2983, D(x): 0.95, D(G(z)): 0.26
# Epoch [38/300], Step [400/600], d_loss: 0.4221, g_loss: 3.6819, D(x): 0.88, D(G(z)): 0.12
# Epoch [38/300], Step [600/600], d_loss: 0.3123, g_loss: 4.4614, D(x): 0.94, D(G(z)): 0.14
# Saving fake_images-0039.png
# Epoch [39/300], Step [200/600], d_loss: 0.3475, g_loss: 4.5999, D(x): 0.92, D(G(z)): 0.13
# Epoch [39/300], Step [400/600], d_loss: 0.7231, g_loss: 3.8409, D(x): 0.77, D(G(z)): 0.12
# Epoch [39/300], Step [600/600], d_loss: 0.6380, g_loss: 3.2773, D(x): 0.82, D(G(z)): 0.17
# Saving fake_images-0040.png
# Epoch [40/300], Step [200/600], d_loss: 0.5442, g_loss: 2.8491, D(x): 0.92, D(G(z)): 0.20
# Epoch [40/300], Step [400/600], d_loss: 0.4334, g_loss: 3.1839, D(x): 0.83, D(G(z)): 0.09
# Epoch [40/300], Step [600/600], d_loss: 0.6519, g_loss: 2.0867, D(x): 0.88, D(G(z)): 0.27
# Saving fake_images-0041.png
# Epoch [41/300], Step [200/600], d_loss: 0.3838, g_loss: 2.6155, D(x): 0.89, D(G(z)): 0.16
# Epoch [41/300], Step [400/600], d_loss: 0.6520, g_loss: 2.8834, D(x): 0.81, D(G(z)): 0.16
# Epoch [41/300], Step [600/600], d_loss: 0.5694, g_loss: 3.1372, D(x): 0.87, D(G(z)): 0.20
# Saving fake_images-0042.png
# Epoch [42/300], Step [200/600], d_loss: 0.6820, g_loss: 2.4503, D(x): 0.86, D(G(z)): 0.30
# Epoch [42/300], Step [400/600], d_loss: 0.3670, g_loss: 2.7855, D(x): 0.90, D(G(z)): 0.15
# Epoch [42/300], Step [600/600], d_loss: 0.5914, g_loss: 2.6648, D(x): 0.79, D(G(z)): 0.16
# Saving fake_images-0043.png
# Epoch [43/300], Step [200/600], d_loss: 0.4956, g_loss: 3.0662, D(x): 0.84, D(G(z)): 0.15
# Epoch [43/300], Step [400/600], d_loss: 0.5975, g_loss: 2.5899, D(x): 0.76, D(G(z)): 0.09
# Epoch [43/300], Step [600/600], d_loss: 0.6707, g_loss: 3.0432, D(x): 0.84, D(G(z)): 0.22
# Saving fake_images-0044.png
# Epoch [44/300], Step [200/600], d_loss: 0.5302, g_loss: 2.4269, D(x): 0.85, D(G(z)): 0.20
# Epoch [44/300], Step [400/600], d_loss: 0.6932, g_loss: 2.5032, D(x): 0.77, D(G(z)): 0.19
# Epoch [44/300], Step [600/600], d_loss: 1.0090, g_loss: 2.0981, D(x): 0.69, D(G(z)): 0.21
# Saving fake_images-0045.png
# Epoch [45/300], Step [200/600], d_loss: 0.7528, g_loss: 2.1842, D(x): 0.80, D(G(z)): 0.24
# Epoch [45/300], Step [400/600], d_loss: 0.5999, g_loss: 2.8365, D(x): 0.91, D(G(z)): 0.27
# Epoch [45/300], Step [600/600], d_loss: 0.4788, g_loss: 1.9668, D(x): 0.83, D(G(z)): 0.15
# Saving fake_images-0046.png
# Epoch [46/300], Step [200/600], d_loss: 0.5185, g_loss: 2.9570, D(x): 0.88, D(G(z)): 0.23
# Epoch [46/300], Step [400/600], d_loss: 0.5605, g_loss: 2.7123, D(x): 0.81, D(G(z)): 0.16
# Epoch [46/300], Step [600/600], d_loss: 0.7907, g_loss: 2.2660, D(x): 0.84, D(G(z)): 0.30
# Saving fake_images-0047.png
# Epoch [47/300], Step [200/600], d_loss: 0.4024, g_loss: 2.9241, D(x): 0.88, D(G(z)): 0.17
# Epoch [47/300], Step [400/600], d_loss: 0.5548, g_loss: 2.3227, D(x): 0.84, D(G(z)): 0.18
# Epoch [47/300], Step [600/600], d_loss: 0.5329, g_loss: 1.8131, D(x): 0.82, D(G(z)): 0.16
# Saving fake_images-0048.png
# Epoch [48/300], Step [200/600], d_loss: 0.5241, g_loss: 2.4004, D(x): 0.88, D(G(z)): 0.22
# Epoch [48/300], Step [400/600], d_loss: 0.4091, g_loss: 2.6760, D(x): 0.87, D(G(z)): 0.14
# Epoch [48/300], Step [600/600], d_loss: 0.3290, g_loss: 3.5645, D(x): 0.91, D(G(z)): 0.11
# Saving fake_images-0049.png
# Epoch [49/300], Step [200/600], d_loss: 0.2591, g_loss: 5.9128, D(x): 0.96, D(G(z)): 0.13
# Epoch [49/300], Step [400/600], d_loss: 0.2001, g_loss: 4.4362, D(x): 0.91, D(G(z)): 0.05
# Epoch [49/300], Step [600/600], d_loss: 0.5453, g_loss: 3.2793, D(x): 0.83, D(G(z)): 0.10
# Saving fake_images-0050.png
# Epoch [50/300], Step [200/600], d_loss: 0.4548, g_loss: 4.3264, D(x): 0.90, D(G(z)): 0.18
# Epoch [50/300], Step [400/600], d_loss: 0.3393, g_loss: 4.3891, D(x): 0.84, D(G(z)): 0.09
# Epoch [50/300], Step [600/600], d_loss: 0.4325, g_loss: 2.7473, D(x): 0.89, D(G(z)): 0.16
# Saving fake_images-0051.png
# Epoch [51/300], Step [200/600], d_loss: 0.4053, g_loss: 2.9795, D(x): 0.92, D(G(z)): 0.21
# Epoch [51/300], Step [400/600], d_loss: 0.3644, g_loss: 3.7677, D(x): 0.89, D(G(z)): 0.14
# Epoch [51/300], Step [600/600], d_loss: 0.4234, g_loss: 2.7943, D(x): 0.90, D(G(z)): 0.19
# Saving fake_images-0052.png
# Epoch [52/300], Step [200/600], d_loss: 0.5372, g_loss: 3.5437, D(x): 0.82, D(G(z)): 0.17
# Epoch [52/300], Step [400/600], d_loss: 0.5602, g_loss: 2.4509, D(x): 0.80, D(G(z)): 0.18
# Epoch [52/300], Step [600/600], d_loss: 0.5928, g_loss: 1.8906, D(x): 0.81, D(G(z)): 0.18
# Saving fake_images-0053.png
# Epoch [53/300], Step [200/600], d_loss: 0.5881, g_loss: 3.0130, D(x): 0.80, D(G(z)): 0.15
# Epoch [53/300], Step [400/600], d_loss: 0.5796, g_loss: 2.2814, D(x): 0.84, D(G(z)): 0.21
# Epoch [53/300], Step [600/600], d_loss: 0.4744, g_loss: 2.5776, D(x): 0.90, D(G(z)): 0.24
# Saving fake_images-0054.png
# Epoch [54/300], Step [200/600], d_loss: 0.6633, g_loss: 2.4164, D(x): 0.79, D(G(z)): 0.18
# Epoch [54/300], Step [400/600], d_loss: 0.7059, g_loss: 2.4280, D(x): 0.74, D(G(z)): 0.18
# Epoch [54/300], Step [600/600], d_loss: 0.7415, g_loss: 1.9909, D(x): 0.76, D(G(z)): 0.25
# Saving fake_images-0055.png
# Epoch [55/300], Step [200/600], d_loss: 0.5955, g_loss: 2.7511, D(x): 0.84, D(G(z)): 0.23
# Epoch [55/300], Step [400/600], d_loss: 0.7076, g_loss: 2.8193, D(x): 0.76, D(G(z)): 0.20
# Epoch [55/300], Step [600/600], d_loss: 0.7728, g_loss: 2.6758, D(x): 0.71, D(G(z)): 0.10
# Saving fake_images-0056.png
# Epoch [56/300], Step [200/600], d_loss: 0.7308, g_loss: 2.1493, D(x): 0.88, D(G(z)): 0.33
# Epoch [56/300], Step [400/600], d_loss: 0.7022, g_loss: 2.4581, D(x): 0.77, D(G(z)): 0.23
# Epoch [56/300], Step [600/600], d_loss: 0.6577, g_loss: 2.2562, D(x): 0.78, D(G(z)): 0.22
# Saving fake_images-0057.png
# Epoch [57/300], Step [200/600], d_loss: 0.9662, g_loss: 2.3446, D(x): 0.74, D(G(z)): 0.29
# Epoch [57/300], Step [400/600], d_loss: 0.8045, g_loss: 2.3305, D(x): 0.66, D(G(z)): 0.12
# Epoch [57/300], Step [600/600], d_loss: 0.7209, g_loss: 2.0138, D(x): 0.82, D(G(z)): 0.25
# Saving fake_images-0058.png
# Epoch [58/300], Step [200/600], d_loss: 0.4757, g_loss: 2.9724, D(x): 0.85, D(G(z)): 0.19
# Epoch [58/300], Step [400/600], d_loss: 0.8115, g_loss: 2.2333, D(x): 0.64, D(G(z)): 0.12
# Epoch [58/300], Step [600/600], d_loss: 0.7930, g_loss: 1.9370, D(x): 0.79, D(G(z)): 0.28
# Saving fake_images-0059.png
# Epoch [59/300], Step [200/600], d_loss: 0.8151, g_loss: 2.1158, D(x): 0.71, D(G(z)): 0.18
# Epoch [59/300], Step [400/600], d_loss: 0.5329, g_loss: 2.8315, D(x): 0.78, D(G(z)): 0.13
# Epoch [59/300], Step [600/600], d_loss: 0.6933, g_loss: 2.9082, D(x): 0.73, D(G(z)): 0.15
# Saving fake_images-0060.png
# Epoch [60/300], Step [200/600], d_loss: 0.5863, g_loss: 2.5888, D(x): 0.81, D(G(z)): 0.21
# Epoch [60/300], Step [400/600], d_loss: 0.5685, g_loss: 2.6436, D(x): 0.77, D(G(z)): 0.12
# Epoch [60/300], Step [600/600], d_loss: 0.6383, g_loss: 2.0244, D(x): 0.80, D(G(z)): 0.23
# Saving fake_images-0061.png
# Epoch [61/300], Step [200/600], d_loss: 0.6872, g_loss: 2.6922, D(x): 0.79, D(G(z)): 0.23
# Epoch [61/300], Step [400/600], d_loss: 0.6971, g_loss: 2.3199, D(x): 0.80, D(G(z)): 0.22
# Epoch [61/300], Step [600/600], d_loss: 0.6296, g_loss: 2.5643, D(x): 0.77, D(G(z)): 0.16
# Saving fake_images-0062.png
# Epoch [62/300], Step [200/600], d_loss: 0.4636, g_loss: 3.6225, D(x): 0.85, D(G(z)): 0.14
# Epoch [62/300], Step [400/600], d_loss: 0.5952, g_loss: 2.3569, D(x): 0.81, D(G(z)): 0.22
# Epoch [62/300], Step [600/600], d_loss: 0.4813, g_loss: 2.9036, D(x): 0.82, D(G(z)): 0.16
# Saving fake_images-0063.png
# Epoch [63/300], Step [200/600], d_loss: 0.5703, g_loss: 2.2641, D(x): 0.84, D(G(z)): 0.23
# Epoch [63/300], Step [400/600], d_loss: 0.5904, g_loss: 2.9222, D(x): 0.80, D(G(z)): 0.21
# Epoch [63/300], Step [600/600], d_loss: 0.4348, g_loss: 3.1268, D(x): 0.83, D(G(z)): 0.13
# Saving fake_images-0064.png
# Epoch [64/300], Step [200/600], d_loss: 0.6044, g_loss: 2.3985, D(x): 0.80, D(G(z)): 0.20
# Epoch [64/300], Step [400/600], d_loss: 0.5271, g_loss: 2.7265, D(x): 0.86, D(G(z)): 0.22
# Epoch [64/300], Step [600/600], d_loss: 0.7143, g_loss: 2.2017, D(x): 0.78, D(G(z)): 0.24
# Saving fake_images-0065.png
# Epoch [65/300], Step [200/600], d_loss: 0.6430, g_loss: 2.3650, D(x): 0.75, D(G(z)): 0.17
# Epoch [65/300], Step [400/600], d_loss: 0.6865, g_loss: 2.0010, D(x): 0.78, D(G(z)): 0.22
# Epoch [65/300], Step [600/600], d_loss: 0.6890, g_loss: 3.0419, D(x): 0.75, D(G(z)): 0.16
# Saving fake_images-0066.png
# Epoch [66/300], Step [200/600], d_loss: 0.7374, g_loss: 2.1865, D(x): 0.76, D(G(z)): 0.26
# Epoch [66/300], Step [400/600], d_loss: 0.6466, g_loss: 2.0769, D(x): 0.83, D(G(z)): 0.28
# Epoch [66/300], Step [600/600], d_loss: 0.6692, g_loss: 1.5916, D(x): 0.77, D(G(z)): 0.19
# Saving fake_images-0067.png
# Epoch [67/300], Step [200/600], d_loss: 0.7320, g_loss: 2.2080, D(x): 0.79, D(G(z)): 0.27
# Epoch [67/300], Step [400/600], d_loss: 0.7579, g_loss: 2.0739, D(x): 0.69, D(G(z)): 0.16
# Epoch [67/300], Step [600/600], d_loss: 0.6366, g_loss: 2.8977, D(x): 0.81, D(G(z)): 0.25
# Saving fake_images-0068.png
# Epoch [68/300], Step [200/600], d_loss: 0.6290, g_loss: 2.0169, D(x): 0.79, D(G(z)): 0.22
# Epoch [68/300], Step [400/600], d_loss: 0.5976, g_loss: 3.1466, D(x): 0.83, D(G(z)): 0.23
# Epoch [68/300], Step [600/600], d_loss: 0.8657, g_loss: 1.6988, D(x): 0.75, D(G(z)): 0.29
# Saving fake_images-0069.png
# Epoch [69/300], Step [200/600], d_loss: 0.7491, g_loss: 2.4031, D(x): 0.75, D(G(z)): 0.20
# Epoch [69/300], Step [400/600], d_loss: 0.6506, g_loss: 2.5740, D(x): 0.75, D(G(z)): 0.16
# Epoch [69/300], Step [600/600], d_loss: 0.8026, g_loss: 2.2540, D(x): 0.78, D(G(z)): 0.25
# Saving fake_images-0070.png
# Epoch [70/300], Step [200/600], d_loss: 0.6703, g_loss: 2.7736, D(x): 0.78, D(G(z)): 0.23
# Epoch [70/300], Step [400/600], d_loss: 0.8420, g_loss: 2.8627, D(x): 0.77, D(G(z)): 0.32
# Epoch [70/300], Step [600/600], d_loss: 0.6027, g_loss: 1.9185, D(x): 0.82, D(G(z)): 0.24
# Saving fake_images-0071.png
# Epoch [71/300], Step [200/600], d_loss: 0.6373, g_loss: 2.4497, D(x): 0.72, D(G(z)): 0.10
# Epoch [71/300], Step [400/600], d_loss: 0.6822, g_loss: 2.4241, D(x): 0.74, D(G(z)): 0.18
# Epoch [71/300], Step [600/600], d_loss: 0.7655, g_loss: 1.9260, D(x): 0.66, D(G(z)): 0.13
# Saving fake_images-0072.png
# Epoch [72/300], Step [200/600], d_loss: 0.5713, g_loss: 1.6377, D(x): 0.79, D(G(z)): 0.19
# Epoch [72/300], Step [400/600], d_loss: 0.9326, g_loss: 1.9567, D(x): 0.73, D(G(z)): 0.27
# Epoch [72/300], Step [600/600], d_loss: 0.6463, g_loss: 1.8704, D(x): 0.80, D(G(z)): 0.24
# Saving fake_images-0073.png
# Epoch [73/300], Step [200/600], d_loss: 0.9455, g_loss: 1.9036, D(x): 0.78, D(G(z)): 0.35
# Epoch [73/300], Step [400/600], d_loss: 0.8664, g_loss: 1.5979, D(x): 0.65, D(G(z)): 0.14
# Epoch [73/300], Step [600/600], d_loss: 0.7469, g_loss: 1.8953, D(x): 0.80, D(G(z)): 0.27
# Saving fake_images-0074.png
# Epoch [74/300], Step [200/600], d_loss: 0.5665, g_loss: 2.1885, D(x): 0.80, D(G(z)): 0.20
# Epoch [74/300], Step [400/600], d_loss: 0.5888, g_loss: 2.2556, D(x): 0.80, D(G(z)): 0.19
# Epoch [74/300], Step [600/600], d_loss: 0.6165, g_loss: 2.3467, D(x): 0.78, D(G(z)): 0.19
# Saving fake_images-0075.png
# Epoch [75/300], Step [200/600], d_loss: 0.6804, g_loss: 2.5271, D(x): 0.81, D(G(z)): 0.27
# Epoch [75/300], Step [400/600], d_loss: 0.8237, g_loss: 1.9952, D(x): 0.82, D(G(z)): 0.32
# Epoch [75/300], Step [600/600], d_loss: 0.8396, g_loss: 2.8793, D(x): 0.76, D(G(z)): 0.25
# Saving fake_images-0076.png
# Epoch [76/300], Step [200/600], d_loss: 0.6165, g_loss: 2.2510, D(x): 0.79, D(G(z)): 0.24
# Epoch [76/300], Step [400/600], d_loss: 0.8883, g_loss: 1.3704, D(x): 0.72, D(G(z)): 0.27
# Epoch [76/300], Step [600/600], d_loss: 0.6773, g_loss: 1.8970, D(x): 0.85, D(G(z)): 0.30
# Saving fake_images-0077.png
# Epoch [77/300], Step [200/600], d_loss: 0.7565, g_loss: 2.0966, D(x): 0.81, D(G(z)): 0.29
# Epoch [77/300], Step [400/600], d_loss: 0.6045, g_loss: 2.2913, D(x): 0.77, D(G(z)): 0.17
# Epoch [77/300], Step [600/600], d_loss: 0.8692, g_loss: 2.1837, D(x): 0.77, D(G(z)): 0.33
# Saving fake_images-0078.png
# Epoch [78/300], Step [200/600], d_loss: 0.6502, g_loss: 2.7443, D(x): 0.71, D(G(z)): 0.13
# Epoch [78/300], Step [400/600], d_loss: 0.7399, g_loss: 2.2687, D(x): 0.69, D(G(z)): 0.15
# Epoch [78/300], Step [600/600], d_loss: 0.6356, g_loss: 1.8262, D(x): 0.77, D(G(z)): 0.19
# Saving fake_images-0079.png
# Epoch [79/300], Step [200/600], d_loss: 0.5037, g_loss: 2.4222, D(x): 0.82, D(G(z)): 0.18
# Epoch [79/300], Step [400/600], d_loss: 0.7501, g_loss: 1.6882, D(x): 0.73, D(G(z)): 0.19
# Epoch [79/300], Step [600/600], d_loss: 0.7480, g_loss: 2.2120, D(x): 0.75, D(G(z)): 0.24
# Saving fake_images-0080.png
# Epoch [80/300], Step [200/600], d_loss: 0.8618, g_loss: 1.8802, D(x): 0.78, D(G(z)): 0.30
# Epoch [80/300], Step [400/600], d_loss: 0.7463, g_loss: 1.6882, D(x): 0.80, D(G(z)): 0.28
# Epoch [80/300], Step [600/600], d_loss: 0.7640, g_loss: 2.5771, D(x): 0.84, D(G(z)): 0.33
# Saving fake_images-0081.png
# Epoch [81/300], Step [200/600], d_loss: 0.5292, g_loss: 2.1779, D(x): 0.84, D(G(z)): 0.23
# Epoch [81/300], Step [400/600], d_loss: 0.6900, g_loss: 2.0092, D(x): 0.81, D(G(z)): 0.27
# Epoch [81/300], Step [600/600], d_loss: 0.6988, g_loss: 2.3286, D(x): 0.74, D(G(z)): 0.16
# Saving fake_images-0082.png
# Epoch [82/300], Step [200/600], d_loss: 0.8014, g_loss: 1.8866, D(x): 0.76, D(G(z)): 0.26
# Epoch [82/300], Step [400/600], d_loss: 0.6236, g_loss: 1.9790, D(x): 0.77, D(G(z)): 0.18
# Epoch [82/300], Step [600/600], d_loss: 0.6130, g_loss: 2.4547, D(x): 0.77, D(G(z)): 0.18
# Saving fake_images-0083.png
# Epoch [83/300], Step [200/600], d_loss: 0.8556, g_loss: 1.7074, D(x): 0.78, D(G(z)): 0.32
# Epoch [83/300], Step [400/600], d_loss: 0.8048, g_loss: 1.7709, D(x): 0.76, D(G(z)): 0.28
# Epoch [83/300], Step [600/600], d_loss: 0.6979, g_loss: 2.1456, D(x): 0.72, D(G(z)): 0.19
# Saving fake_images-0084.png
# Epoch [84/300], Step [200/600], d_loss: 0.9210, g_loss: 1.8617, D(x): 0.66, D(G(z)): 0.20
# Epoch [84/300], Step [400/600], d_loss: 0.8296, g_loss: 2.6765, D(x): 0.71, D(G(z)): 0.18
# Epoch [84/300], Step [600/600], d_loss: 0.7299, g_loss: 2.1806, D(x): 0.74, D(G(z)): 0.22
# Saving fake_images-0085.png
# Epoch [85/300], Step [200/600], d_loss: 0.6376, g_loss: 2.5273, D(x): 0.80, D(G(z)): 0.24
# Epoch [85/300], Step [400/600], d_loss: 0.9868, g_loss: 1.7975, D(x): 0.76, D(G(z)): 0.34
# Epoch [85/300], Step [600/600], d_loss: 0.6924, g_loss: 1.9708, D(x): 0.79, D(G(z)): 0.24
# Saving fake_images-0086.png
# Epoch [86/300], Step [200/600], d_loss: 0.8272, g_loss: 2.0952, D(x): 0.72, D(G(z)): 0.23
# Epoch [86/300], Step [400/600], d_loss: 0.8296, g_loss: 1.6102, D(x): 0.77, D(G(z)): 0.29
# Epoch [86/300], Step [600/600], d_loss: 0.8187, g_loss: 1.7262, D(x): 0.80, D(G(z)): 0.32
# Saving fake_images-0087.png
# Epoch [87/300], Step [200/600], d_loss: 0.9352, g_loss: 2.0120, D(x): 0.70, D(G(z)): 0.22
# Epoch [87/300], Step [400/600], d_loss: 0.9849, g_loss: 1.5495, D(x): 0.69, D(G(z)): 0.30
# Epoch [87/300], Step [600/600], d_loss: 0.6306, g_loss: 2.1381, D(x): 0.76, D(G(z)): 0.20
# Saving fake_images-0088.png
# Epoch [88/300], Step [200/600], d_loss: 0.6803, g_loss: 2.3366, D(x): 0.80, D(G(z)): 0.26
# Epoch [88/300], Step [400/600], d_loss: 0.6626, g_loss: 1.8877, D(x): 0.84, D(G(z)): 0.28
# Epoch [88/300], Step [600/600], d_loss: 0.7072, g_loss: 1.9296, D(x): 0.74, D(G(z)): 0.21
# Saving fake_images-0089.png
# Epoch [89/300], Step [200/600], d_loss: 0.7180, g_loss: 2.2575, D(x): 0.70, D(G(z)): 0.18
# Epoch [89/300], Step [400/600], d_loss: 0.8637, g_loss: 1.9505, D(x): 0.81, D(G(z)): 0.37
# Epoch [89/300], Step [600/600], d_loss: 0.8780, g_loss: 2.0827, D(x): 0.76, D(G(z)): 0.33
# Saving fake_images-0090.png
# Epoch [90/300], Step [200/600], d_loss: 0.8808, g_loss: 1.6139, D(x): 0.85, D(G(z)): 0.43
# Epoch [90/300], Step [400/600], d_loss: 1.1232, g_loss: 1.6625, D(x): 0.64, D(G(z)): 0.24
# Epoch [90/300], Step [600/600], d_loss: 0.8393, g_loss: 1.6886, D(x): 0.65, D(G(z)): 0.20
# Saving fake_images-0091.png
# Epoch [91/300], Step [200/600], d_loss: 0.7272, g_loss: 1.7243, D(x): 0.81, D(G(z)): 0.29
# Epoch [91/300], Step [400/600], d_loss: 0.8802, g_loss: 1.4100, D(x): 0.75, D(G(z)): 0.34
# Epoch [91/300], Step [600/600], d_loss: 0.6501, g_loss: 2.0207, D(x): 0.75, D(G(z)): 0.20
# Saving fake_images-0092.png
# Epoch [92/300], Step [200/600], d_loss: 0.8775, g_loss: 1.5718, D(x): 0.81, D(G(z)): 0.38
# Epoch [92/300], Step [400/600], d_loss: 0.6926, g_loss: 1.8186, D(x): 0.76, D(G(z)): 0.25
# Epoch [92/300], Step [600/600], d_loss: 1.0210, g_loss: 2.1320, D(x): 0.68, D(G(z)): 0.28
# Saving fake_images-0093.png
# Epoch [93/300], Step [200/600], d_loss: 0.7682, g_loss: 1.4196, D(x): 0.80, D(G(z)): 0.32
# Epoch [93/300], Step [400/600], d_loss: 0.9620, g_loss: 1.7524, D(x): 0.66, D(G(z)): 0.25
# Epoch [93/300], Step [600/600], d_loss: 0.8053, g_loss: 1.6061, D(x): 0.78, D(G(z)): 0.29
# Saving fake_images-0094.png
# Epoch [94/300], Step [200/600], d_loss: 0.9130, g_loss: 1.9010, D(x): 0.67, D(G(z)): 0.26
# Epoch [94/300], Step [400/600], d_loss: 0.8541, g_loss: 1.8556, D(x): 0.74, D(G(z)): 0.29
# Epoch [94/300], Step [600/600], d_loss: 1.0355, g_loss: 1.5574, D(x): 0.69, D(G(z)): 0.32
# Saving fake_images-0095.png
# Epoch [95/300], Step [200/600], d_loss: 0.7398, g_loss: 1.7751, D(x): 0.73, D(G(z)): 0.22
# Epoch [95/300], Step [400/600], d_loss: 0.8162, g_loss: 1.8130, D(x): 0.72, D(G(z)): 0.27
# Epoch [95/300], Step [600/600], d_loss: 0.6526, g_loss: 2.6500, D(x): 0.73, D(G(z)): 0.15
# Saving fake_images-0096.png
# Epoch [96/300], Step [200/600], d_loss: 0.7458, g_loss: 2.1249, D(x): 0.78, D(G(z)): 0.27
# Epoch [96/300], Step [400/600], d_loss: 0.7203, g_loss: 2.0196, D(x): 0.71, D(G(z)): 0.21
# Epoch [96/300], Step [600/600], d_loss: 0.9919, g_loss: 1.5692, D(x): 0.73, D(G(z)): 0.34
# Saving fake_images-0097.png
# Epoch [97/300], Step [200/600], d_loss: 0.8301, g_loss: 1.6941, D(x): 0.72, D(G(z)): 0.25
# Epoch [97/300], Step [400/600], d_loss: 0.7433, g_loss: 2.3909, D(x): 0.85, D(G(z)): 0.32
# Epoch [97/300], Step [600/600], d_loss: 0.8855, g_loss: 1.8922, D(x): 0.79, D(G(z)): 0.33
# Saving fake_images-0098.png
# Epoch [98/300], Step [200/600], d_loss: 0.8234, g_loss: 1.7453, D(x): 0.76, D(G(z)): 0.32
# Epoch [98/300], Step [400/600], d_loss: 0.6769, g_loss: 1.7640, D(x): 0.79, D(G(z)): 0.27
# Epoch [98/300], Step [600/600], d_loss: 0.8663, g_loss: 1.8173, D(x): 0.82, D(G(z)): 0.36
# Saving fake_images-0099.png
# Epoch [99/300], Step [200/600], d_loss: 0.8068, g_loss: 1.9300, D(x): 0.77, D(G(z)): 0.31
# Epoch [99/300], Step [400/600], d_loss: 0.9399, g_loss: 1.5864, D(x): 0.78, D(G(z)): 0.37
# Epoch [99/300], Step [600/600], d_loss: 0.6824, g_loss: 1.8505, D(x): 0.76, D(G(z)): 0.23
# Saving fake_images-0100.png
# Epoch [100/300], Step [200/600], d_loss: 0.7071, g_loss: 1.9490, D(x): 0.78, D(G(z)): 0.27
# Epoch [100/300], Step [400/600], d_loss: 0.8081, g_loss: 1.9302, D(x): 0.74, D(G(z)): 0.26
# Epoch [100/300], Step [600/600], d_loss: 0.9132, g_loss: 1.8766, D(x): 0.73, D(G(z)): 0.31
# Saving fake_images-0101.png
# Epoch [101/300], Step [200/600], d_loss: 0.6330, g_loss: 2.3452, D(x): 0.76, D(G(z)): 0.22
# Epoch [101/300], Step [400/600], d_loss: 0.7505, g_loss: 1.9655, D(x): 0.76, D(G(z)): 0.28
# Epoch [101/300], Step [600/600], d_loss: 0.6273, g_loss: 2.1927, D(x): 0.79, D(G(z)): 0.21
# Saving fake_images-0102.png
# Epoch [102/300], Step [200/600], d_loss: 0.8936, g_loss: 1.5621, D(x): 0.71, D(G(z)): 0.28
# Epoch [102/300], Step [400/600], d_loss: 0.7950, g_loss: 1.8247, D(x): 0.72, D(G(z)): 0.26
# Epoch [102/300], Step [600/600], d_loss: 0.9800, g_loss: 1.5437, D(x): 0.70, D(G(z)): 0.33
# Saving fake_images-0103.png
# Epoch [103/300], Step [200/600], d_loss: 0.7166, g_loss: 2.0120, D(x): 0.77, D(G(z)): 0.26
# Epoch [103/300], Step [400/600], d_loss: 0.9424, g_loss: 1.5275, D(x): 0.79, D(G(z)): 0.39
# Epoch [103/300], Step [600/600], d_loss: 0.9501, g_loss: 1.4707, D(x): 0.71, D(G(z)): 0.34
# Saving fake_images-0104.png
# Epoch [104/300], Step [200/600], d_loss: 0.7027, g_loss: 2.2485, D(x): 0.73, D(G(z)): 0.22
# Epoch [104/300], Step [400/600], d_loss: 1.1736, g_loss: 1.8669, D(x): 0.75, D(G(z)): 0.42
# Epoch [104/300], Step [600/600], d_loss: 0.8779, g_loss: 2.3181, D(x): 0.70, D(G(z)): 0.21
# Saving fake_images-0105.png
# Epoch [105/300], Step [200/600], d_loss: 0.7174, g_loss: 1.8441, D(x): 0.80, D(G(z)): 0.26
# Epoch [105/300], Step [400/600], d_loss: 0.9407, g_loss: 2.1788, D(x): 0.64, D(G(z)): 0.22
# Epoch [105/300], Step [600/600], d_loss: 1.0374, g_loss: 1.8120, D(x): 0.66, D(G(z)): 0.26
# Saving fake_images-0106.png
# Epoch [106/300], Step [200/600], d_loss: 0.7639, g_loss: 1.4494, D(x): 0.74, D(G(z)): 0.25
# Epoch [106/300], Step [400/600], d_loss: 1.0291, g_loss: 1.5832, D(x): 0.79, D(G(z)): 0.38
# Epoch [106/300], Step [600/600], d_loss: 0.9156, g_loss: 1.7515, D(x): 0.69, D(G(z)): 0.26
# Saving fake_images-0107.png
# Epoch [107/300], Step [200/600], d_loss: 0.7216, g_loss: 1.9004, D(x): 0.78, D(G(z)): 0.27
# Epoch [107/300], Step [400/600], d_loss: 0.7624, g_loss: 2.5067, D(x): 0.73, D(G(z)): 0.24
# Epoch [107/300], Step [600/600], d_loss: 0.9419, g_loss: 2.3380, D(x): 0.61, D(G(z)): 0.14
# Saving fake_images-0108.png
# Epoch [108/300], Step [200/600], d_loss: 0.8852, g_loss: 1.8772, D(x): 0.67, D(G(z)): 0.27
# Epoch [108/300], Step [400/600], d_loss: 0.7072, g_loss: 1.6899, D(x): 0.74, D(G(z)): 0.23
# Epoch [108/300], Step [600/600], d_loss: 0.9751, g_loss: 1.4682, D(x): 0.68, D(G(z)): 0.27
# Saving fake_images-0109.png
# Epoch [109/300], Step [200/600], d_loss: 0.7256, g_loss: 1.8707, D(x): 0.68, D(G(z)): 0.20
# Epoch [109/300], Step [400/600], d_loss: 0.9372, g_loss: 1.4140, D(x): 0.64, D(G(z)): 0.21
# Epoch [109/300], Step [600/600], d_loss: 0.7205, g_loss: 2.2909, D(x): 0.78, D(G(z)): 0.24
# Saving fake_images-0110.png
# Epoch [110/300], Step [200/600], d_loss: 0.8299, g_loss: 1.8367, D(x): 0.71, D(G(z)): 0.26
# Epoch [110/300], Step [400/600], d_loss: 0.8540, g_loss: 2.1945, D(x): 0.65, D(G(z)): 0.17
# Epoch [110/300], Step [600/600], d_loss: 0.7881, g_loss: 1.4531, D(x): 0.78, D(G(z)): 0.29
# Saving fake_images-0111.png
# Epoch [111/300], Step [200/600], d_loss: 0.6693, g_loss: 2.0803, D(x): 0.82, D(G(z)): 0.27
# Epoch [111/300], Step [400/600], d_loss: 0.8776, g_loss: 2.1252, D(x): 0.71, D(G(z)): 0.27
# Epoch [111/300], Step [600/600], d_loss: 0.6336, g_loss: 2.0717, D(x): 0.78, D(G(z)): 0.24
# Saving fake_images-0112.png
# Epoch [112/300], Step [200/600], d_loss: 0.8701, g_loss: 1.8156, D(x): 0.81, D(G(z)): 0.36
# Epoch [112/300], Step [400/600], d_loss: 0.7771, g_loss: 1.7761, D(x): 0.80, D(G(z)): 0.32
# Epoch [112/300], Step [600/600], d_loss: 0.9253, g_loss: 1.8713, D(x): 0.81, D(G(z)): 0.38
# Saving fake_images-0113.png
# Epoch [113/300], Step [200/600], d_loss: 0.7897, g_loss: 1.9388, D(x): 0.73, D(G(z)): 0.26
# Epoch [113/300], Step [400/600], d_loss: 0.7438, g_loss: 1.7667, D(x): 0.72, D(G(z)): 0.23
# Epoch [113/300], Step [600/600], d_loss: 0.7850, g_loss: 1.7542, D(x): 0.76, D(G(z)): 0.26
# Saving fake_images-0114.png
# Epoch [114/300], Step [200/600], d_loss: 0.9714, g_loss: 2.1403, D(x): 0.64, D(G(z)): 0.23
# Epoch [114/300], Step [400/600], d_loss: 1.0354, g_loss: 1.7592, D(x): 0.67, D(G(z)): 0.33
# Epoch [114/300], Step [600/600], d_loss: 0.8471, g_loss: 1.6094, D(x): 0.69, D(G(z)): 0.24
# Saving fake_images-0115.png
# Epoch [115/300], Step [200/600], d_loss: 0.8504, g_loss: 2.0232, D(x): 0.68, D(G(z)): 0.21
# Epoch [115/300], Step [400/600], d_loss: 0.7132, g_loss: 1.8980, D(x): 0.73, D(G(z)): 0.23
# Epoch [115/300], Step [600/600], d_loss: 0.7588, g_loss: 1.6824, D(x): 0.78, D(G(z)): 0.30
# Saving fake_images-0116.png
# Epoch [116/300], Step [200/600], d_loss: 0.8998, g_loss: 1.5967, D(x): 0.71, D(G(z)): 0.27
# Epoch [116/300], Step [400/600], d_loss: 0.7008, g_loss: 1.7391, D(x): 0.83, D(G(z)): 0.32
# Epoch [116/300], Step [600/600], d_loss: 0.8024, g_loss: 1.9606, D(x): 0.74, D(G(z)): 0.25
# Saving fake_images-0117.png
# Epoch [117/300], Step [200/600], d_loss: 0.7967, g_loss: 1.6554, D(x): 0.77, D(G(z)): 0.29
# Epoch [117/300], Step [400/600], d_loss: 0.7164, g_loss: 2.3739, D(x): 0.74, D(G(z)): 0.20
# Epoch [117/300], Step [600/600], d_loss: 0.6972, g_loss: 1.6814, D(x): 0.71, D(G(z)): 0.19
# Saving fake_images-0118.png
# Epoch [118/300], Step [200/600], d_loss: 0.7921, g_loss: 1.4768, D(x): 0.78, D(G(z)): 0.31
# Epoch [118/300], Step [400/600], d_loss: 0.9257, g_loss: 1.4367, D(x): 0.81, D(G(z)): 0.39
# Epoch [118/300], Step [600/600], d_loss: 0.7872, g_loss: 2.1362, D(x): 0.74, D(G(z)): 0.26
# Saving fake_images-0119.png
# Epoch [119/300], Step [200/600], d_loss: 1.1459, g_loss: 1.7310, D(x): 0.62, D(G(z)): 0.29
# Epoch [119/300], Step [400/600], d_loss: 0.9698, g_loss: 2.0142, D(x): 0.72, D(G(z)): 0.30
# Epoch [119/300], Step [600/600], d_loss: 0.8588, g_loss: 1.8866, D(x): 0.67, D(G(z)): 0.23
# Saving fake_images-0120.png
# Epoch [120/300], Step [200/600], d_loss: 1.0441, g_loss: 1.3824, D(x): 0.64, D(G(z)): 0.27
# Epoch [120/300], Step [400/600], d_loss: 0.8407, g_loss: 1.8724, D(x): 0.77, D(G(z)): 0.32
# Epoch [120/300], Step [600/600], d_loss: 0.8242, g_loss: 1.3003, D(x): 0.74, D(G(z)): 0.31
# Saving fake_images-0121.png
# Epoch [121/300], Step [200/600], d_loss: 0.9785, g_loss: 1.5723, D(x): 0.75, D(G(z)): 0.38
# Epoch [121/300], Step [400/600], d_loss: 0.9539, g_loss: 2.3010, D(x): 0.64, D(G(z)): 0.20
# Epoch [121/300], Step [600/600], d_loss: 1.1061, g_loss: 1.3005, D(x): 0.68, D(G(z)): 0.35
# Saving fake_images-0122.png
# Epoch [122/300], Step [200/600], d_loss: 0.7130, g_loss: 2.3365, D(x): 0.73, D(G(z)): 0.22
# Epoch [122/300], Step [400/600], d_loss: 0.6958, g_loss: 1.5179, D(x): 0.77, D(G(z)): 0.27
# Epoch [122/300], Step [600/600], d_loss: 0.9270, g_loss: 1.5677, D(x): 0.66, D(G(z)): 0.22
# Saving fake_images-0123.png
# Epoch [123/300], Step [200/600], d_loss: 0.8504, g_loss: 2.0868, D(x): 0.75, D(G(z)): 0.32
# Epoch [123/300], Step [400/600], d_loss: 0.8182, g_loss: 2.0430, D(x): 0.77, D(G(z)): 0.28
# Epoch [123/300], Step [600/600], d_loss: 0.7982, g_loss: 2.0510, D(x): 0.66, D(G(z)): 0.15
# Saving fake_images-0124.png
# Epoch [124/300], Step [200/600], d_loss: 0.8514, g_loss: 1.3782, D(x): 0.71, D(G(z)): 0.27
# Epoch [124/300], Step [400/600], d_loss: 0.6613, g_loss: 2.5167, D(x): 0.75, D(G(z)): 0.20
# Epoch [124/300], Step [600/600], d_loss: 0.8132, g_loss: 1.3525, D(x): 0.72, D(G(z)): 0.29
# Saving fake_images-0125.png
# Epoch [125/300], Step [200/600], d_loss: 0.9475, g_loss: 1.4332, D(x): 0.74, D(G(z)): 0.36
# Epoch [125/300], Step [400/600], d_loss: 0.9660, g_loss: 1.3539, D(x): 0.73, D(G(z)): 0.33
# Epoch [125/300], Step [600/600], d_loss: 0.6460, g_loss: 1.9657, D(x): 0.76, D(G(z)): 0.21
# Saving fake_images-0126.png
# Epoch [126/300], Step [200/600], d_loss: 0.8409, g_loss: 1.8551, D(x): 0.73, D(G(z)): 0.27
# Epoch [126/300], Step [400/600], d_loss: 0.8600, g_loss: 1.9985, D(x): 0.73, D(G(z)): 0.26
# Epoch [126/300], Step [600/600], d_loss: 0.6874, g_loss: 2.6667, D(x): 0.74, D(G(z)): 0.19
# Saving fake_images-0127.png
# Epoch [127/300], Step [200/600], d_loss: 0.7186, g_loss: 2.0152, D(x): 0.73, D(G(z)): 0.21
# Epoch [127/300], Step [400/600], d_loss: 0.9326, g_loss: 1.4873, D(x): 0.65, D(G(z)): 0.23
# Epoch [127/300], Step [600/600], d_loss: 0.9903, g_loss: 1.3658, D(x): 0.71, D(G(z)): 0.32
# Saving fake_images-0128.png
# Epoch [128/300], Step [200/600], d_loss: 0.8665, g_loss: 1.9127, D(x): 0.74, D(G(z)): 0.30
# Epoch [128/300], Step [400/600], d_loss: 1.0783, g_loss: 1.6889, D(x): 0.73, D(G(z)): 0.39
# Epoch [128/300], Step [600/600], d_loss: 0.8540, g_loss: 2.0090, D(x): 0.75, D(G(z)): 0.32
# Saving fake_images-0129.png
# Epoch [129/300], Step [200/600], d_loss: 1.0225, g_loss: 1.9047, D(x): 0.63, D(G(z)): 0.26
# Epoch [129/300], Step [400/600], d_loss: 0.7322, g_loss: 1.8493, D(x): 0.81, D(G(z)): 0.33
# Epoch [129/300], Step [600/600], d_loss: 0.8942, g_loss: 1.7991, D(x): 0.75, D(G(z)): 0.32
# Saving fake_images-0130.png
# Epoch [130/300], Step [200/600], d_loss: 1.1033, g_loss: 1.6569, D(x): 0.70, D(G(z)): 0.38
# Epoch [130/300], Step [400/600], d_loss: 0.7400, g_loss: 1.6321, D(x): 0.75, D(G(z)): 0.27
# Epoch [130/300], Step [600/600], d_loss: 0.9210, g_loss: 1.6720, D(x): 0.72, D(G(z)): 0.33
# Saving fake_images-0131.png
# Epoch [131/300], Step [200/600], d_loss: 0.9552, g_loss: 1.2641, D(x): 0.71, D(G(z)): 0.35
# Epoch [131/300], Step [400/600], d_loss: 0.9546, g_loss: 1.6051, D(x): 0.70, D(G(z)): 0.32
# Epoch [131/300], Step [600/600], d_loss: 0.9122, g_loss: 1.8609, D(x): 0.62, D(G(z)): 0.20
# Saving fake_images-0132.png
# Epoch [132/300], Step [200/600], d_loss: 0.9631, g_loss: 1.2178, D(x): 0.69, D(G(z)): 0.31
# Epoch [132/300], Step [400/600], d_loss: 0.6843, g_loss: 2.1804, D(x): 0.75, D(G(z)): 0.21
# Epoch [132/300], Step [600/600], d_loss: 0.9539, g_loss: 1.7148, D(x): 0.76, D(G(z)): 0.36
# Saving fake_images-0133.png
# Epoch [133/300], Step [200/600], d_loss: 0.8578, g_loss: 1.8168, D(x): 0.70, D(G(z)): 0.26
# Epoch [133/300], Step [400/600], d_loss: 0.7017, g_loss: 1.4487, D(x): 0.73, D(G(z)): 0.22
# Epoch [133/300], Step [600/600], d_loss: 1.0859, g_loss: 1.8714, D(x): 0.55, D(G(z)): 0.20
# Saving fake_images-0134.png
# Epoch [134/300], Step [200/600], d_loss: 0.9986, g_loss: 1.9625, D(x): 0.67, D(G(z)): 0.31
# Epoch [134/300], Step [400/600], d_loss: 0.9725, g_loss: 1.2603, D(x): 0.73, D(G(z)): 0.38
# Epoch [134/300], Step [600/600], d_loss: 1.0753, g_loss: 1.4922, D(x): 0.63, D(G(z)): 0.30
# Saving fake_images-0135.png
# Epoch [135/300], Step [200/600], d_loss: 0.9068, g_loss: 1.5551, D(x): 0.69, D(G(z)): 0.29
# Epoch [135/300], Step [400/600], d_loss: 0.9829, g_loss: 1.0371, D(x): 0.76, D(G(z)): 0.38
# Epoch [135/300], Step [600/600], d_loss: 0.8539, g_loss: 1.9005, D(x): 0.70, D(G(z)): 0.27
# Saving fake_images-0136.png
# Epoch [136/300], Step [200/600], d_loss: 0.8669, g_loss: 1.4123, D(x): 0.79, D(G(z)): 0.37
# Epoch [136/300], Step [400/600], d_loss: 0.9393, g_loss: 1.5595, D(x): 0.73, D(G(z)): 0.35
# Epoch [136/300], Step [600/600], d_loss: 0.8905, g_loss: 1.6984, D(x): 0.70, D(G(z)): 0.28
# Saving fake_images-0137.png
# Epoch [137/300], Step [200/600], d_loss: 0.9137, g_loss: 1.5759, D(x): 0.65, D(G(z)): 0.25
# Epoch [137/300], Step [400/600], d_loss: 0.8648, g_loss: 2.2981, D(x): 0.73, D(G(z)): 0.30
# Epoch [137/300], Step [600/600], d_loss: 1.0946, g_loss: 1.6514, D(x): 0.71, D(G(z)): 0.39
# Saving fake_images-0138.png
# Epoch [138/300], Step [200/600], d_loss: 1.2222, g_loss: 1.6746, D(x): 0.54, D(G(z)): 0.24
# Epoch [138/300], Step [400/600], d_loss: 0.7997, g_loss: 1.7014, D(x): 0.72, D(G(z)): 0.26
# Epoch [138/300], Step [600/600], d_loss: 0.8229, g_loss: 1.8320, D(x): 0.69, D(G(z)): 0.22
# Saving fake_images-0139.png
# Epoch [139/300], Step [200/600], d_loss: 0.7604, g_loss: 1.7477, D(x): 0.73, D(G(z)): 0.26
# Epoch [139/300], Step [400/600], d_loss: 0.9737, g_loss: 1.4706, D(x): 0.73, D(G(z)): 0.35
# Epoch [139/300], Step [600/600], d_loss: 0.8936, g_loss: 2.2816, D(x): 0.75, D(G(z)): 0.33
# Saving fake_images-0140.png
# Epoch [140/300], Step [200/600], d_loss: 0.9176, g_loss: 1.4578, D(x): 0.67, D(G(z)): 0.27
# Epoch [140/300], Step [400/600], d_loss: 0.9121, g_loss: 1.6892, D(x): 0.67, D(G(z)): 0.28
# Epoch [140/300], Step [600/600], d_loss: 0.8372, g_loss: 1.4464, D(x): 0.76, D(G(z)): 0.31
# Saving fake_images-0141.png
# Epoch [141/300], Step [200/600], d_loss: 1.0305, g_loss: 1.5475, D(x): 0.68, D(G(z)): 0.35
# Epoch [141/300], Step [400/600], d_loss: 0.8879, g_loss: 1.6565, D(x): 0.65, D(G(z)): 0.24
# Epoch [141/300], Step [600/600], d_loss: 1.0678, g_loss: 1.7273, D(x): 0.65, D(G(z)): 0.28
# Saving fake_images-0142.png
# Epoch [142/300], Step [200/600], d_loss: 0.8716, g_loss: 1.3760, D(x): 0.68, D(G(z)): 0.27
# Epoch [142/300], Step [400/600], d_loss: 0.9872, g_loss: 1.3705, D(x): 0.71, D(G(z)): 0.36
# Epoch [142/300], Step [600/600], d_loss: 0.8822, g_loss: 1.3652, D(x): 0.68, D(G(z)): 0.29
# Saving fake_images-0143.png
# Epoch [143/300], Step [200/600], d_loss: 1.0131, g_loss: 1.4860, D(x): 0.60, D(G(z)): 0.23
# Epoch [143/300], Step [400/600], d_loss: 0.9009, g_loss: 1.3409, D(x): 0.74, D(G(z)): 0.34
# Epoch [143/300], Step [600/600], d_loss: 1.0538, g_loss: 1.0814, D(x): 0.70, D(G(z)): 0.38
# Saving fake_images-0144.png
# Epoch [144/300], Step [200/600], d_loss: 0.8016, g_loss: 1.3778, D(x): 0.76, D(G(z)): 0.31
# Epoch [144/300], Step [400/600], d_loss: 0.6991, g_loss: 2.1176, D(x): 0.73, D(G(z)): 0.23
# Epoch [144/300], Step [600/600], d_loss: 0.8529, g_loss: 1.7222, D(x): 0.69, D(G(z)): 0.27
# Saving fake_images-0145.png
# Epoch [145/300], Step [200/600], d_loss: 0.8354, g_loss: 2.1496, D(x): 0.72, D(G(z)): 0.25
# Epoch [145/300], Step [400/600], d_loss: 1.0090, g_loss: 1.8272, D(x): 0.66, D(G(z)): 0.30
# Epoch [145/300], Step [600/600], d_loss: 1.0934, g_loss: 1.5799, D(x): 0.75, D(G(z)): 0.41
# Saving fake_images-0146.png
# Epoch [146/300], Step [200/600], d_loss: 0.9094, g_loss: 1.8397, D(x): 0.67, D(G(z)): 0.26
# Epoch [146/300], Step [400/600], d_loss: 0.8513, g_loss: 1.7473, D(x): 0.68, D(G(z)): 0.22
# Epoch [146/300], Step [600/600], d_loss: 0.8707, g_loss: 2.0780, D(x): 0.61, D(G(z)): 0.20
# Saving fake_images-0147.png
# Epoch [147/300], Step [200/600], d_loss: 1.0692, g_loss: 1.6303, D(x): 0.67, D(G(z)): 0.35
# Epoch [147/300], Step [400/600], d_loss: 0.7643, g_loss: 1.6222, D(x): 0.73, D(G(z)): 0.25
# Epoch [147/300], Step [600/600], d_loss: 0.9389, g_loss: 1.9843, D(x): 0.66, D(G(z)): 0.27
# Saving fake_images-0148.png
# Epoch [148/300], Step [200/600], d_loss: 1.0551, g_loss: 1.7505, D(x): 0.70, D(G(z)): 0.34
# Epoch [148/300], Step [400/600], d_loss: 1.0051, g_loss: 1.3768, D(x): 0.66, D(G(z)): 0.28
# Epoch [148/300], Step [600/600], d_loss: 0.8449, g_loss: 1.6896, D(x): 0.73, D(G(z)): 0.30
# Saving fake_images-0149.png
# Epoch [149/300], Step [200/600], d_loss: 0.9974, g_loss: 1.3849, D(x): 0.66, D(G(z)): 0.31
# Epoch [149/300], Step [400/600], d_loss: 1.0696, g_loss: 1.4480, D(x): 0.71, D(G(z)): 0.35
# Epoch [149/300], Step [600/600], d_loss: 0.9096, g_loss: 1.5219, D(x): 0.77, D(G(z)): 0.36
# Saving fake_images-0150.png
# Epoch [150/300], Step [200/600], d_loss: 1.1111, g_loss: 1.6248, D(x): 0.53, D(G(z)): 0.21
# Epoch [150/300], Step [400/600], d_loss: 1.0525, g_loss: 1.3732, D(x): 0.75, D(G(z)): 0.40
# Epoch [150/300], Step [600/600], d_loss: 1.1800, g_loss: 1.4114, D(x): 0.63, D(G(z)): 0.36
# Saving fake_images-0151.png
# Epoch [151/300], Step [200/600], d_loss: 0.9468, g_loss: 1.4704, D(x): 0.77, D(G(z)): 0.36
# Epoch [151/300], Step [400/600], d_loss: 0.9003, g_loss: 1.4163, D(x): 0.75, D(G(z)): 0.34
# Epoch [151/300], Step [600/600], d_loss: 1.0081, g_loss: 1.0860, D(x): 0.71, D(G(z)): 0.38
# Saving fake_images-0152.png
# Epoch [152/300], Step [200/600], d_loss: 0.7970, g_loss: 1.3989, D(x): 0.73, D(G(z)): 0.29
# Epoch [152/300], Step [400/600], d_loss: 0.8471, g_loss: 1.5952, D(x): 0.70, D(G(z)): 0.27
# Epoch [152/300], Step [600/600], d_loss: 0.9784, g_loss: 1.3770, D(x): 0.77, D(G(z)): 0.41
# Saving fake_images-0153.png
# Epoch [153/300], Step [200/600], d_loss: 0.9675, g_loss: 1.6129, D(x): 0.72, D(G(z)): 0.32
# Epoch [153/300], Step [400/600], d_loss: 0.9308, g_loss: 1.3494, D(x): 0.78, D(G(z)): 0.39
# Epoch [153/300], Step [600/600], d_loss: 0.9038, g_loss: 1.6767, D(x): 0.74, D(G(z)): 0.33
# Saving fake_images-0154.png
# Epoch [154/300], Step [200/600], d_loss: 0.9220, g_loss: 1.5775, D(x): 0.79, D(G(z)): 0.40
# Epoch [154/300], Step [400/600], d_loss: 0.8927, g_loss: 1.8947, D(x): 0.65, D(G(z)): 0.24
# Epoch [154/300], Step [600/600], d_loss: 0.8945, g_loss: 1.6734, D(x): 0.74, D(G(z)): 0.33
# Saving fake_images-0155.png
# Epoch [155/300], Step [200/600], d_loss: 1.0300, g_loss: 1.4380, D(x): 0.63, D(G(z)): 0.28
# Epoch [155/300], Step [400/600], d_loss: 0.9332, g_loss: 1.5827, D(x): 0.70, D(G(z)): 0.30
# Epoch [155/300], Step [600/600], d_loss: 0.9262, g_loss: 1.5877, D(x): 0.69, D(G(z)): 0.32
# Saving fake_images-0156.png
# Epoch [156/300], Step [200/600], d_loss: 0.7987, g_loss: 1.7277, D(x): 0.76, D(G(z)): 0.29
# Epoch [156/300], Step [400/600], d_loss: 0.9583, g_loss: 1.3097, D(x): 0.80, D(G(z)): 0.38
# Epoch [156/300], Step [600/600], d_loss: 1.0123, g_loss: 1.3195, D(x): 0.76, D(G(z)): 0.41
# Saving fake_images-0157.png
# Epoch [157/300], Step [200/600], d_loss: 0.6588, g_loss: 1.9314, D(x): 0.74, D(G(z)): 0.20
# Epoch [157/300], Step [400/600], d_loss: 0.7957, g_loss: 1.4908, D(x): 0.76, D(G(z)): 0.30
# Epoch [157/300], Step [600/600], d_loss: 0.9303, g_loss: 1.4278, D(x): 0.68, D(G(z)): 0.28
# Saving fake_images-0158.png
# Epoch [158/300], Step [200/600], d_loss: 0.9251, g_loss: 1.9801, D(x): 0.69, D(G(z)): 0.27
# Epoch [158/300], Step [400/600], d_loss: 0.9941, g_loss: 1.5130, D(x): 0.61, D(G(z)): 0.25
# Epoch [158/300], Step [600/600], d_loss: 1.0419, g_loss: 1.1936, D(x): 0.67, D(G(z)): 0.34
# Saving fake_images-0159.png
# Epoch [159/300], Step [200/600], d_loss: 1.0066, g_loss: 1.8235, D(x): 0.69, D(G(z)): 0.31
# Epoch [159/300], Step [400/600], d_loss: 0.8204, g_loss: 1.5027, D(x): 0.70, D(G(z)): 0.26
# Epoch [159/300], Step [600/600], d_loss: 0.9533, g_loss: 1.5314, D(x): 0.62, D(G(z)): 0.22
# Saving fake_images-0160.png
# Epoch [160/300], Step [200/600], d_loss: 1.0481, g_loss: 1.9923, D(x): 0.64, D(G(z)): 0.27
# ...
# Epoch [247/300], Step [400/600], d_loss: 1.0169, g_loss: 1.4023, D(x): 0.66, D(G(z)): 0.33
# Epoch [247/300], Step [600/600], d_loss: 0.7594, g_loss: 1.6703, D(x): 0.71, D(G(z)): 0.23
# Saving fake_images-0248.png
# Epoch [248/300], Step [200/600], d_loss: 0.8991, g_loss: 1.6672, D(x): 0.70, D(G(z)): 0.32
# Epoch [248/300], Step [400/600], d_loss: 0.9279, g_loss: 1.2965, D(x): 0.73, D(G(z)): 0.34
# Epoch [248/300], Step [600/600], d_loss: 1.1965, g_loss: 1.5545, D(x): 0.53, D(G(z)): 0.27
# Saving fake_images-0249.png
# Epoch [249/300], Step [200/600], d_loss: 0.9394, g_loss: 1.7301, D(x): 0.69, D(G(z)): 0.31
# Epoch [249/300], Step [400/600], d_loss: 0.8622, g_loss: 1.2602, D(x): 0.73, D(G(z)): 0.33
# Epoch [249/300], Step [600/600], d_loss: 0.9107, g_loss: 1.7693, D(x): 0.72, D(G(z)): 0.30
# Saving fake_images-0250.png
# Epoch [250/300], Step [200/600], d_loss: 0.8872, g_loss: 1.9309, D(x): 0.67, D(G(z)): 0.27
# Epoch [250/300], Step [400/600], d_loss: 0.9133, g_loss: 1.5471, D(x): 0.66, D(G(z)): 0.28
# Epoch [250/300], Step [600/600], d_loss: 0.9932, g_loss: 1.5231, D(x): 0.72, D(G(z)): 0.34
# Saving fake_images-0251.png
# Epoch [251/300], Step [200/600], d_loss: 0.9568, g_loss: 1.0965, D(x): 0.71, D(G(z)): 0.36
# Epoch [251/300], Step [400/600], d_loss: 0.7970, g_loss: 1.6186, D(x): 0.74, D(G(z)): 0.30
# Epoch [251/300], Step [600/600], d_loss: 1.0062, g_loss: 1.8410, D(x): 0.64, D(G(z)): 0.28
# Saving fake_images-0252.png
# Epoch [252/300], Step [200/600], d_loss: 0.8427, g_loss: 1.8870, D(x): 0.74, D(G(z)): 0.31
# Epoch [252/300], Step [400/600], d_loss: 0.8400, g_loss: 1.5864, D(x): 0.72, D(G(z)): 0.31
# Epoch [252/300], Step [600/600], d_loss: 1.0778, g_loss: 1.2607, D(x): 0.64, D(G(z)): 0.33
# Saving fake_images-0253.png
# Epoch [253/300], Step [200/600], d_loss: 1.0109, g_loss: 1.2925, D(x): 0.66, D(G(z)): 0.32
# Epoch [253/300], Step [400/600], d_loss: 0.8529, g_loss: 1.7425, D(x): 0.70, D(G(z)): 0.29
# Epoch [253/300], Step [600/600], d_loss: 0.7911, g_loss: 1.4031, D(x): 0.72, D(G(z)): 0.27
# Saving fake_images-0254.png
# Epoch [254/300], Step [200/600], d_loss: 1.1155, g_loss: 1.6549, D(x): 0.60, D(G(z)): 0.28
# Epoch [254/300], Step [400/600], d_loss: 1.0978, g_loss: 1.5770, D(x): 0.73, D(G(z)): 0.41
# Epoch [254/300], Step [600/600], d_loss: 0.9566, g_loss: 1.4396, D(x): 0.69, D(G(z)): 0.32
# Saving fake_images-0255.png
# Epoch [255/300], Step [200/600], d_loss: 0.8325, g_loss: 1.7082, D(x): 0.70, D(G(z)): 0.28
# Epoch [255/300], Step [400/600], d_loss: 0.9387, g_loss: 1.0551, D(x): 0.76, D(G(z)): 0.39
# Epoch [255/300], Step [600/600], d_loss: 1.0839, g_loss: 1.6848, D(x): 0.66, D(G(z)): 0.35
# Saving fake_images-0256.png
# Epoch [256/300], Step [200/600], d_loss: 1.1043, g_loss: 1.2429, D(x): 0.72, D(G(z)): 0.41
# Epoch [256/300], Step [400/600], d_loss: 0.8714, g_loss: 1.5467, D(x): 0.79, D(G(z)): 0.38
# Epoch [256/300], Step [600/600], d_loss: 0.8808, g_loss: 1.5825, D(x): 0.68, D(G(z)): 0.26
# Saving fake_images-0257.png
# Epoch [257/300], Step [200/600], d_loss: 0.9983, g_loss: 1.6330, D(x): 0.66, D(G(z)): 0.31
# Epoch [257/300], Step [400/600], d_loss: 0.8406, g_loss: 1.6614, D(x): 0.70, D(G(z)): 0.28
# Epoch [257/300], Step [600/600], d_loss: 1.0090, g_loss: 1.6275, D(x): 0.65, D(G(z)): 0.31
# Saving fake_images-0258.png
# Epoch [258/300], Step [200/600], d_loss: 1.0452, g_loss: 1.2560, D(x): 0.79, D(G(z)): 0.47
# Epoch [258/300], Step [400/600], d_loss: 0.8214, g_loss: 1.7597, D(x): 0.67, D(G(z)): 0.22
# Epoch [258/300], Step [600/600], d_loss: 0.8611, g_loss: 1.3812, D(x): 0.73, D(G(z)): 0.32
# Saving fake_images-0259.png
# Epoch [259/300], Step [200/600], d_loss: 1.0333, g_loss: 1.5793, D(x): 0.60, D(G(z)): 0.26
# Epoch [259/300], Step [400/600], d_loss: 0.9754, g_loss: 1.3407, D(x): 0.74, D(G(z)): 0.39
# Epoch [259/300], Step [600/600], d_loss: 0.9887, g_loss: 1.4507, D(x): 0.66, D(G(z)): 0.30
# Saving fake_images-0260.png
# Epoch [260/300], Step [200/600], d_loss: 1.0030, g_loss: 1.3895, D(x): 0.65, D(G(z)): 0.31
# Epoch [260/300], Step [400/600], d_loss: 0.9284, g_loss: 1.7140, D(x): 0.70, D(G(z)): 0.34
# Epoch [260/300], Step [600/600], d_loss: 0.9635, g_loss: 1.6172, D(x): 0.69, D(G(z)): 0.33
# Saving fake_images-0261.png
# Epoch [261/300], Step [200/600], d_loss: 1.0382, g_loss: 1.2360, D(x): 0.72, D(G(z)): 0.40
# Epoch [261/300], Step [400/600], d_loss: 0.9760, g_loss: 1.2188, D(x): 0.69, D(G(z)): 0.35
# Epoch [261/300], Step [600/600], d_loss: 1.0927, g_loss: 1.4156, D(x): 0.61, D(G(z)): 0.33
# Saving fake_images-0262.png
# Epoch [262/300], Step [200/600], d_loss: 0.7451, g_loss: 1.5571, D(x): 0.72, D(G(z)): 0.27
# Epoch [262/300], Step [400/600], d_loss: 0.8758, g_loss: 1.2619, D(x): 0.68, D(G(z)): 0.30
# Epoch [262/300], Step [600/600], d_loss: 0.8506, g_loss: 1.4617, D(x): 0.70, D(G(z)): 0.30
# Saving fake_images-0263.png
# Epoch [263/300], Step [200/600], d_loss: 0.9137, g_loss: 1.5977, D(x): 0.75, D(G(z)): 0.38
# Epoch [263/300], Step [400/600], d_loss: 0.8006, g_loss: 1.3859, D(x): 0.76, D(G(z)): 0.33
# Epoch [263/300], Step [600/600], d_loss: 0.8746, g_loss: 1.5955, D(x): 0.66, D(G(z)): 0.25
# Saving fake_images-0264.png
# Epoch [264/300], Step [200/600], d_loss: 0.9523, g_loss: 1.3999, D(x): 0.71, D(G(z)): 0.34
# Epoch [264/300], Step [400/600], d_loss: 0.9536, g_loss: 1.3272, D(x): 0.75, D(G(z)): 0.40
# Epoch [264/300], Step [600/600], d_loss: 0.8367, g_loss: 1.6572, D(x): 0.76, D(G(z)): 0.30
# Saving fake_images-0265.png
# Epoch [265/300], Step [200/600], d_loss: 0.9874, g_loss: 1.2770, D(x): 0.72, D(G(z)): 0.39
# Epoch [265/300], Step [400/600], d_loss: 0.9995, g_loss: 1.7475, D(x): 0.60, D(G(z)): 0.23
# Epoch [265/300], Step [600/600], d_loss: 0.9007, g_loss: 1.2874, D(x): 0.73, D(G(z)): 0.34
# Saving fake_images-0266.png
# Epoch [266/300], Step [200/600], d_loss: 0.8979, g_loss: 1.4111, D(x): 0.79, D(G(z)): 0.39
# Epoch [266/300], Step [400/600], d_loss: 1.0041, g_loss: 1.5422, D(x): 0.71, D(G(z)): 0.33
# Epoch [266/300], Step [600/600], d_loss: 0.9233, g_loss: 1.4283, D(x): 0.68, D(G(z)): 0.31
# Saving fake_images-0267.png
# Epoch [267/300], Step [200/600], d_loss: 0.9897, g_loss: 1.5154, D(x): 0.64, D(G(z)): 0.30
# Epoch [267/300], Step [400/600], d_loss: 0.9973, g_loss: 1.7127, D(x): 0.74, D(G(z)): 0.38
# Epoch [267/300], Step [600/600], d_loss: 1.1818, g_loss: 1.8350, D(x): 0.61, D(G(z)): 0.29
# Saving fake_images-0268.png
# Epoch [268/300], Step [200/600], d_loss: 1.0533, g_loss: 1.2957, D(x): 0.66, D(G(z)): 0.33
# Epoch [268/300], Step [400/600], d_loss: 0.8983, g_loss: 1.2399, D(x): 0.77, D(G(z)): 0.38
# Epoch [268/300], Step [600/600], d_loss: 1.2611, g_loss: 1.7699, D(x): 0.59, D(G(z)): 0.31
# Saving fake_images-0269.png
# Epoch [269/300], Step [200/600], d_loss: 0.9003, g_loss: 1.7573, D(x): 0.79, D(G(z)): 0.38
# Epoch [269/300], Step [400/600], d_loss: 0.9100, g_loss: 1.5206, D(x): 0.70, D(G(z)): 0.31
# Epoch [269/300], Step [600/600], d_loss: 1.0170, g_loss: 1.4140, D(x): 0.75, D(G(z)): 0.43
# Saving fake_images-0270.png
# Epoch [270/300], Step [200/600], d_loss: 0.8608, g_loss: 1.5286, D(x): 0.71, D(G(z)): 0.31
# Epoch [270/300], Step [400/600], d_loss: 1.0176, g_loss: 1.4623, D(x): 0.68, D(G(z)): 0.32
# Epoch [270/300], Step [600/600], d_loss: 0.8551, g_loss: 1.4758, D(x): 0.68, D(G(z)): 0.30
# Saving fake_images-0271.png
# Epoch [271/300], Step [200/600], d_loss: 1.0190, g_loss: 1.2451, D(x): 0.69, D(G(z)): 0.35
# Epoch [271/300], Step [400/600], d_loss: 1.0137, g_loss: 1.5333, D(x): 0.71, D(G(z)): 0.35
# Epoch [271/300], Step [600/600], d_loss: 0.9201, g_loss: 1.8310, D(x): 0.67, D(G(z)): 0.28
# Saving fake_images-0272.png
# Epoch [272/300], Step [200/600], d_loss: 0.9268, g_loss: 1.5103, D(x): 0.67, D(G(z)): 0.29
# Epoch [272/300], Step [400/600], d_loss: 0.9596, g_loss: 1.3620, D(x): 0.74, D(G(z)): 0.35
# Epoch [272/300], Step [600/600], d_loss: 1.1169, g_loss: 1.2535, D(x): 0.71, D(G(z)): 0.40
# Saving fake_images-0273.png
# Epoch [273/300], Step [200/600], d_loss: 0.9190, g_loss: 1.8185, D(x): 0.68, D(G(z)): 0.29
# Epoch [273/300], Step [400/600], d_loss: 0.9437, g_loss: 1.3934, D(x): 0.64, D(G(z)): 0.28
# Epoch [273/300], Step [600/600], d_loss: 0.9249, g_loss: 1.2124, D(x): 0.69, D(G(z)): 0.30
# Saving fake_images-0274.png
# Epoch [274/300], Step [200/600], d_loss: 0.9013, g_loss: 1.1807, D(x): 0.77, D(G(z)): 0.37
# Epoch [274/300], Step [400/600], d_loss: 1.0478, g_loss: 1.3605, D(x): 0.70, D(G(z)): 0.37
# Epoch [274/300], Step [600/600], d_loss: 0.9596, g_loss: 1.6486, D(x): 0.67, D(G(z)): 0.29
# Saving fake_images-0275.png
# Epoch [275/300], Step [200/600], d_loss: 0.9149, g_loss: 1.3465, D(x): 0.73, D(G(z)): 0.34
# Epoch [275/300], Step [400/600], d_loss: 0.9087, g_loss: 1.4224, D(x): 0.71, D(G(z)): 0.32
# Epoch [275/300], Step [600/600], d_loss: 0.8961, g_loss: 1.6426, D(x): 0.68, D(G(z)): 0.30
# Saving fake_images-0276.png
# Epoch [276/300], Step [200/600], d_loss: 0.9164, g_loss: 1.3196, D(x): 0.74, D(G(z)): 0.36
# Epoch [276/300], Step [400/600], d_loss: 0.9461, g_loss: 1.8443, D(x): 0.65, D(G(z)): 0.25
# Epoch [276/300], Step [600/600], d_loss: 0.8666, g_loss: 1.5814, D(x): 0.72, D(G(z)): 0.32
# Saving fake_images-0277.png
# Epoch [277/300], Step [200/600], d_loss: 0.8159, g_loss: 1.6474, D(x): 0.72, D(G(z)): 0.26
# Epoch [277/300], Step [400/600], d_loss: 0.9823, g_loss: 1.9324, D(x): 0.59, D(G(z)): 0.21
# Epoch [277/300], Step [600/600], d_loss: 1.0113, g_loss: 1.4367, D(x): 0.74, D(G(z)): 0.35
# Saving fake_images-0278.png
# Epoch [278/300], Step [200/600], d_loss: 0.7729, g_loss: 1.4395, D(x): 0.75, D(G(z)): 0.31
# Epoch [278/300], Step [400/600], d_loss: 1.1056, g_loss: 1.2504, D(x): 0.64, D(G(z)): 0.35
# Epoch [278/300], Step [600/600], d_loss: 1.0472, g_loss: 1.4017, D(x): 0.73, D(G(z)): 0.39
# Saving fake_images-0279.png
# Epoch [279/300], Step [200/600], d_loss: 1.1101, g_loss: 1.5121, D(x): 0.65, D(G(z)): 0.36
# Epoch [279/300], Step [400/600], d_loss: 0.8334, g_loss: 1.4669, D(x): 0.75, D(G(z)): 0.34
# Epoch [279/300], Step [600/600], d_loss: 0.9402, g_loss: 1.5071, D(x): 0.66, D(G(z)): 0.28
# Saving fake_images-0280.png
# Epoch [280/300], Step [200/600], d_loss: 0.8538, g_loss: 1.3558, D(x): 0.73, D(G(z)): 0.31
# Epoch [280/300], Step [400/600], d_loss: 0.9351, g_loss: 1.4978, D(x): 0.65, D(G(z)): 0.25
# Epoch [280/300], Step [600/600], d_loss: 0.9244, g_loss: 1.6306, D(x): 0.65, D(G(z)): 0.27
# Saving fake_images-0281.png
# Epoch [281/300], Step [200/600], d_loss: 0.9588, g_loss: 1.2128, D(x): 0.69, D(G(z)): 0.32
# Epoch [281/300], Step [400/600], d_loss: 1.0145, g_loss: 1.3084, D(x): 0.70, D(G(z)): 0.37
# Epoch [281/300], Step [600/600], d_loss: 1.0016, g_loss: 1.5291, D(x): 0.68, D(G(z)): 0.33
# Saving fake_images-0282.png
# Epoch [282/300], Step [200/600], d_loss: 0.8622, g_loss: 1.3682, D(x): 0.73, D(G(z)): 0.32
# Epoch [282/300], Step [400/600], d_loss: 0.9939, g_loss: 1.2989, D(x): 0.66, D(G(z)): 0.30
# Epoch [282/300], Step [600/600], d_loss: 1.0032, g_loss: 1.4273, D(x): 0.68, D(G(z)): 0.31
# Saving fake_images-0283.png
# Epoch [283/300], Step [200/600], d_loss: 0.9254, g_loss: 1.3491, D(x): 0.66, D(G(z)): 0.28
# Epoch [283/300], Step [400/600], d_loss: 1.0953, g_loss: 1.4636, D(x): 0.63, D(G(z)): 0.30
# Epoch [283/300], Step [600/600], d_loss: 1.0145, g_loss: 1.2251, D(x): 0.68, D(G(z)): 0.34
# Saving fake_images-0284.png
# Epoch [284/300], Step [200/600], d_loss: 1.0494, g_loss: 1.1692, D(x): 0.74, D(G(z)): 0.41
# Epoch [284/300], Step [400/600], d_loss: 0.8037, g_loss: 1.7440, D(x): 0.72, D(G(z)): 0.29
# Epoch [284/300], Step [600/600], d_loss: 0.7972, g_loss: 1.4410, D(x): 0.73, D(G(z)): 0.28
# Saving fake_images-0285.png
# Epoch [285/300], Step [200/600], d_loss: 0.8819, g_loss: 1.4153, D(x): 0.73, D(G(z)): 0.30
# Epoch [285/300], Step [400/600], d_loss: 0.7592, g_loss: 1.4420, D(x): 0.78, D(G(z)): 0.32
# Epoch [285/300], Step [600/600], d_loss: 0.8770, g_loss: 1.6368, D(x): 0.68, D(G(z)): 0.30
# Saving fake_images-0286.png
# Epoch [286/300], Step [200/600], d_loss: 0.8715, g_loss: 1.2507, D(x): 0.73, D(G(z)): 0.33
# Epoch [286/300], Step [400/600], d_loss: 1.0898, g_loss: 1.4461, D(x): 0.69, D(G(z)): 0.38
# Epoch [286/300], Step [600/600], d_loss: 0.8929, g_loss: 1.5467, D(x): 0.60, D(G(z)): 0.18
# Saving fake_images-0287.png
# Epoch [287/300], Step [200/600], d_loss: 0.9243, g_loss: 1.2047, D(x): 0.74, D(G(z)): 0.36
# Epoch [287/300], Step [400/600], d_loss: 0.9216, g_loss: 1.3856, D(x): 0.69, D(G(z)): 0.32
# Epoch [287/300], Step [600/600], d_loss: 1.0349, g_loss: 1.5739, D(x): 0.70, D(G(z)): 0.34
# Saving fake_images-0288.png
# Epoch [288/300], Step [200/600], d_loss: 0.9265, g_loss: 1.5507, D(x): 0.62, D(G(z)): 0.24
# Epoch [288/300], Step [400/600], d_loss: 0.8776, g_loss: 1.4986, D(x): 0.71, D(G(z)): 0.33
# Epoch [288/300], Step [600/600], d_loss: 1.0434, g_loss: 1.3025, D(x): 0.63, D(G(z)): 0.30
# Saving fake_images-0289.png
# Epoch [289/300], Step [200/600], d_loss: 0.7298, g_loss: 1.6242, D(x): 0.71, D(G(z)): 0.23
# Epoch [289/300], Step [400/600], d_loss: 0.8501, g_loss: 1.7637, D(x): 0.73, D(G(z)): 0.31
# Epoch [289/300], Step [600/600], d_loss: 0.8213, g_loss: 1.2946, D(x): 0.74, D(G(z)): 0.32
# Saving fake_images-0290.png
# Epoch [290/300], Step [200/600], d_loss: 0.9649, g_loss: 1.3021, D(x): 0.74, D(G(z)): 0.37
# Epoch [290/300], Step [400/600], d_loss: 0.9505, g_loss: 1.5560, D(x): 0.67, D(G(z)): 0.30
# Epoch [290/300], Step [600/600], d_loss: 0.9374, g_loss: 1.4001, D(x): 0.65, D(G(z)): 0.30
# Saving fake_images-0291.png
# Epoch [291/300], Step [200/600], d_loss: 1.0541, g_loss: 1.7288, D(x): 0.69, D(G(z)): 0.35
# Epoch [291/300], Step [400/600], d_loss: 0.9720, g_loss: 1.8240, D(x): 0.67, D(G(z)): 0.29
# Epoch [291/300], Step [600/600], d_loss: 0.9460, g_loss: 1.6816, D(x): 0.68, D(G(z)): 0.28
# Saving fake_images-0292.png
# Epoch [292/300], Step [200/600], d_loss: 0.8899, g_loss: 1.3556, D(x): 0.69, D(G(z)): 0.30
# Epoch [292/300], Step [400/600], d_loss: 0.9338, g_loss: 1.6203, D(x): 0.73, D(G(z)): 0.36
# Epoch [292/300], Step [600/600], d_loss: 1.0717, g_loss: 1.6954, D(x): 0.63, D(G(z)): 0.31
# Saving fake_images-0293.png
# Epoch [293/300], Step [200/600], d_loss: 0.8415, g_loss: 1.4190, D(x): 0.75, D(G(z)): 0.34
# Epoch [293/300], Step [400/600], d_loss: 0.9882, g_loss: 1.6775, D(x): 0.69, D(G(z)): 0.32
# Epoch [293/300], Step [600/600], d_loss: 1.0783, g_loss: 1.3346, D(x): 0.64, D(G(z)): 0.30
# Saving fake_images-0294.png
# Epoch [294/300], Step [200/600], d_loss: 1.0204, g_loss: 1.3703, D(x): 0.72, D(G(z)): 0.37
# Epoch [294/300], Step [400/600], d_loss: 0.7253, g_loss: 1.7868, D(x): 0.68, D(G(z)): 0.18
# Epoch [294/300], Step [600/600], d_loss: 0.7996, g_loss: 1.6349, D(x): 0.73, D(G(z)): 0.28
# Saving fake_images-0295.png
# Epoch [295/300], Step [200/600], d_loss: 0.8797, g_loss: 1.4015, D(x): 0.70, D(G(z)): 0.28
# Epoch [295/300], Step [400/600], d_loss: 1.0382, g_loss: 1.6914, D(x): 0.63, D(G(z)): 0.26
# Epoch [295/300], Step [600/600], d_loss: 0.8897, g_loss: 1.2931, D(x): 0.68, D(G(z)): 0.27
# Saving fake_images-0296.png
# Epoch [296/300], Step [200/600], d_loss: 0.9378, g_loss: 1.4706, D(x): 0.68, D(G(z)): 0.32
# Epoch [296/300], Step [400/600], d_loss: 1.0659, g_loss: 1.4365, D(x): 0.60, D(G(z)): 0.29
# Epoch [296/300], Step [600/600], d_loss: 1.0455, g_loss: 1.6204, D(x): 0.70, D(G(z)): 0.40
# Saving fake_images-0297.png
# Epoch [297/300], Step [200/600], d_loss: 0.9705, g_loss: 1.3192, D(x): 0.63, D(G(z)): 0.27
# Epoch [297/300], Step [400/600], d_loss: 1.0367, g_loss: 1.7500, D(x): 0.68, D(G(z)): 0.36
# Epoch [297/300], Step [600/600], d_loss: 1.0337, g_loss: 1.6959, D(x): 0.66, D(G(z)): 0.35
# Saving fake_images-0298.png
# Epoch [298/300], Step [200/600], d_loss: 0.9937, g_loss: 1.3260, D(x): 0.66, D(G(z)): 0.31
# Epoch [298/300], Step [400/600], d_loss: 1.1046, g_loss: 1.2502, D(x): 0.67, D(G(z)): 0.37
# Epoch [298/300], Step [600/600], d_loss: 0.8607, g_loss: 1.8223, D(x): 0.68, D(G(z)): 0.28
# Saving fake_images-0299.png
# Epoch [299/300], Step [200/600], d_loss: 0.8303, g_loss: 1.7904, D(x): 0.68, D(G(z)): 0.25
# Epoch [299/300], Step [400/600], d_loss: 0.7786, g_loss: 1.5314, D(x): 0.76, D(G(z)): 0.31
# Epoch [299/300], Step [600/600], d_loss: 0.9470, g_loss: 1.4916, D(x): 0.65, D(G(z)): 0.27
# Saving fake_images-0300.png
# CPU times: user 5h 59min 43s, sys: 12min 35s, total: 6h 12min 19s
# Wall time: 2h 47min 22s

# %% [markdown]
# Now that we have trained the models, we can save checkpoints.

# %%
# Save the model checkpoints 
torch.save(G.state_dict(), 'G.ckpt')
torch.save(D.state_dict(), 'D.ckpt')

# %% [markdown]
# Here's how the generated images look, after the 10th, 50th, 100th and 300th epochs of training.

# %%
Image('./samples/fake_images-0010.png')

# %%
Image('./samples/fake_images-0050.png')

# %%
Image('./samples/fake_images-0100.png')

# %%
Image('./samples/fake_images-0300.png')

# %%
plt.plot(d_losses, '-')
plt.plot(g_losses, '-')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['Discriminator', 'Generator'])
plt.title('Losses');

# %%
plt.plot(real_scores, '-')
plt.plot(fake_scores, '-')
plt.xlabel('epoch')
plt.ylabel('score')
plt.legend(['Real Score', 'Fake score'])
plt.title('Scores');
